# %%
# !pip install censusgeocode

# %%
import glob
import json
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# # Census Examples

# %% [markdown]
# This notebook uses the `censusgeocode` package in Python (which is simply a wrapper around the US Census' official Geocoder API) to get census geographies for list of addresses or lat/longs
#
# - https://pypi.org/project/censusgeocode/

# %% [markdown]
# ### Step 1 | Grab your data at the address level

# %%
df = pd.read_csv('plants_with_coordinates.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                      plant_name  Plant Code State  Sector Name  \
# 0           0          (3K) 59 Hetcheltown Rd       66729    NY  IPP Non-CHP
# 1           1                0 Hammond St CSG       64876    MA  IPP Non-CHP
# 2           2                    1 Commercial       67464    MA  IPP Non-CHP
# 3           3  10 Briggs Solar NG, LLC (East)       62781    RI  IPP Non-CHP
# 4           4   10 Finderne Avenue Solar, LLC       64023    NJ  IPP Non-CHP
#
#   Prime Movers Fuel Types  Primary Technology  \
# 0           PV        SUN  Solar Photovoltaic
# 1       BA, PV   MWH, SUN            Multiple
# 2       BA, PV   MWH, SUN            Multiple
# 3           PV        SUN  Solar Photovoltaic
# 4           PV        SUN  Solar Photovoltaic
#
#   withdrawal_volume_million_gallons discharge_volume_million_gallons  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   consumption_volume_million_gallons           energy_category  \
# 0                                NaN  Renewable Energy Sources
# 1                                NaN                     Other
# 2                                NaN                     Other
# 3                                NaN  Renewable Energy Sources
# 4                                NaN  Renewable Energy Sources
#
#                                     map_link  longitude   latitude
# 0    map/?center=-73.91048,42.87657&level=14 -73.910480  42.876570
# 1  map/?center=-70.726675,41.808547&level=14 -70.726675  41.808547
# 2        map/?center=-71.237,42.115&level=14 -71.237000  42.115000
# 3    map/?center=-71.49625,41.63269&level=14 -71.496250  41.632690
# 4    map/?center=-74.57594,40.55812&level=14 -74.575940  40.558120

# %%
df['plant_name'].nunique()
# Out:
# 12633

# %%
df.shape
# Out:
# (12661, 15)

# %%
df.to_csv('plants_with_coordinates.csv',index=False)

# %% [markdown]
# ### Step 2 | Geoode Lat/Long if they're not already present
#
# It already exists in this dataset. Census geocode has a function to go from addresss --> lat/long, but I haven't had time to implement it here. This dataset already has lat/longs. Message me if you're struggling with this step.

# %%
import pandas as pd
import requests_cache
import time
from tqdm import tqdm

# Enable caching to speed up repeated requests
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng, retries=3, delay=1):
    url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
    params = {
        "x": lng,
        "y": lat,
        "benchmark": "Public_AR_Census2020",
        "vintage": "Census2020_Census2020",
        "format": "json"
    }
    for attempt in range(retries):
        try:
            response = cache.get(url, params=params, timeout=10)
            response.raise_for_status()
            data = response.json()
            tract = data['result']['geographies']['Census Tracts'][0]
            return tract
        except Exception as e:
            if attempt < retries - 1:
                time.sleep(delay * (attempt + 1))  # Exponential backoff
            else:
                return {"error": str(e), "lat": lat, "lng": lng}

def geocode_all(df, save_path="census_geos_all.csv"):
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing all data"):
        lat, lng = row['latitude'], row['longitude']
        result = geocode(lat, lng)
        results.append(result)

    # Convert the results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results.to_csv(save_path, index=False)

    # Free memory by deleting intermediate data
    del results, df_results  
    print(f"Results saved to {save_path}")

# Now, run this on your DataFrame
geocode_all(df)
# Out:
# Processing all data: 100%|███████████████| 12661/12661 [00:25<00:00, 488.71it/s]
# Results saved to census_geos_all.csv

# %%
# import pandas as pd
# import requests_cache
# import time
# import os
# from tqdm import tqdm

# # Enable caching to speed up repeated requests
# cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

# def geocode(lat, lng, retries=3, delay=1):
#     url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
#     params = {
#         "x": lng,
#         "y": lat,
#         "benchmark": "Public_AR_Census2020",
#         "vintage": "Census2020_Census2020",
#         "format": "json"
#     }
#     for attempt in range(retries):
#         try:
#             response = cache.get(url, params=params, timeout=10)
#             response.raise_for_status()
#             data = response.json()
#             tract = data['result']['geographies']['Census Tracts'][0]
#             return tract
#         except Exception as e:
#             if attempt < retries - 1:
#                 time.sleep(delay * (attempt + 1))  # Exponential backoff
#             else:
#                 return {"error": str(e), "lat": lat, "lng": lng}

# def process_chunk(chunk, chunk_index, save_prefix="census_geos_part"):
#     results = []
#     for _, row in tqdm(chunk.iterrows(), total=len(chunk), desc=f"Processing chunk {chunk_index + 1}"):
#         lat, lng = row['latitude'], row['longitude']
#         result = geocode(lat, lng)
#         results.append(result)

#     # Convert the results into a DataFrame
#     df_chunk = pd.DataFrame(results)
#     output_path = f"{save_prefix}_{chunk_index + 1}.csv"
#     df_chunk.to_csv(output_path, index=False)

#     # Free memory by deleting intermediate data
#     del results, df_chunk  
#     return output_path

# def geocode_in_chunks_safe(df, chunk_size=500, save_prefix="census_geos_part"):
#     total_chunks = (len(df) + chunk_size - 1) // chunk_size  # Calculate number of chunks
    
#     for i in range(total_chunks):
#         output_file = f"{save_prefix}_{i + 1}.csv"
#         print(f"Processing chunk {i + 1} of {total_chunks}")
        
#         # Skip checking if file exists; process each chunk regardless
#         chunk = df.iloc[i*chunk_size : (i+1)*chunk_size]  # Select the chunk
#         process_chunk(chunk, i, save_prefix=save_prefix)
#         time.sleep(2)  # Sleep between requests to avoid hitting API rate limits

# # Now, run this on your DataFrame
# geocode_in_chunks_safe(df)

# %%
# import glob

# # Adjust this pattern to match your saved files
# chunk_files = sorted(glob.glob("census_geos_part_*.csv"))

# # Load and concatenate them
# combined_df = pd.concat([pd.read_csv(f) for f in chunk_files], ignore_index=True)

# # Optional: Save combined result to disk
# combined_df.to_csv("census_geocoded_full.csv", index=False)

# # Check it out
# combined_df.head()

# %%
# combined_df.shape

# %%
census_geos = pd.read_csv('census_geos_all.csv')

# %%
census_geos
# Out:
#        POP100         GEOID    CENTLAT   AREAWATER  STATE  BASENAME  \
# 0      3494.0  3.609303e+10  42.881043     69888.0   36.0    325.02
# 1      6075.0  2.502354e+10  41.857932   4840087.0   25.0   5442.00
# 2      5862.0  2.502141e+10  42.119699    338878.0   25.0   4141.00
# 3      6876.0  4.400302e+10  41.633007    129489.0   44.0    209.03
# 4      7319.0  3.403505e+10  40.562949    620006.0   34.0    510.00
# ...       ...           ...        ...         ...    ...       ...
# 12656  1836.0  8.087001e+09  40.152142    314014.0    8.0      8.00
# 12657  1900.0  1.326995e+10  32.499910   1792585.0   13.0   9503.01
# 12658  3746.0  4.204302e+10  40.257994   2287145.0   42.0    201.00
# 12659  1134.0  1.210502e+10  27.746262  80407214.0   12.0    161.00
# 12660  4156.0  1.608300e+10  42.308988   9856292.0   16.0     16.00
#
#                 OID LSADC FUNCSTAT   INTPTLAT  ...     CENTLON   HU100  \
# 0      2.079074e+13    CT        S  42.881277  ...  -73.913102  1320.0
# 1      2.079021e+13    CT        S  41.858697  ...  -70.744259  2689.0
# 2      2.079026e+13    CT        S  42.120093  ...  -71.205044  2145.0
# 3      2.079023e+13    CT        S  41.633184  ...  -71.517378  2301.0
# 4      2.079031e+13    CT        S  40.563551  ...  -74.571689  2702.0
# ...             ...   ...      ...        ...  ...         ...     ...
# 12656  2.079036e+13    CT        S  40.154192  ... -103.615312   793.0
# 12657  2.079015e+15    CT        S  32.485892  ...  -84.326620  1031.0
# 12658  2.079047e+13    CT        S  40.257558  ...  -76.884192  2764.0
# 12659  2.079037e+13    CT        S  27.745906  ...  -81.973661   482.0
# 12660  2.079015e+15    CT        S  42.306243  ... -114.675063  1553.0
#
#            AREALAND    INTPTLON  MTFCC  UR  COUNTY error lat  lng
# 0      7.206301e+06  -73.911677  G5020   M    93.0   NaN NaN  NaN
# 1      6.948583e+07  -70.745874  G5020   M    23.0   NaN NaN  NaN
# 2      2.839787e+07  -71.203693  G5020   M    21.0   NaN NaN  NaN
# 3      3.166488e+07  -71.524229  G5020   M     3.0   NaN NaN  NaN
# 4      1.127632e+07  -74.570409  G5020   U    35.0   NaN NaN  NaN
# ...             ...         ...    ...  ..     ...   ...  ..  ...
# 12656  8.739758e+08 -103.651230  G5020   M    87.0   NaN NaN  NaN
# 12657  3.932802e+08  -84.327847  G5020   R   269.0   NaN NaN  NaN
# 12658  2.290375e+06  -76.881726  G5020   U    43.0   NaN NaN  NaN
# 12659  2.774396e+08  -81.978291  G5020   R   105.0   NaN NaN  NaN
# 12660  4.059031e+09 -114.670262  G5020   R    83.0   NaN NaN  NaN
#
# [12661 rows x 23 columns]

# %%
census_geos['GEOID'] = census_geos['GEOID'].apply(lambda x: f"{int(x):011d}" if pd.notna(x) else x)

# %%
census_geos
# Out:
#        POP100        GEOID    CENTLAT   AREAWATER  STATE  BASENAME  \
# 0      3494.0  36093032502  42.881043     69888.0   36.0    325.02
# 1      6075.0  25023544200  41.857932   4840087.0   25.0   5442.00
# 2      5862.0  25021414100  42.119699    338878.0   25.0   4141.00
# 3      6876.0  44003020903  41.633007    129489.0   44.0    209.03
# 4      7319.0  34035051000  40.562949    620006.0   34.0    510.00
# ...       ...          ...        ...         ...    ...       ...
# 12656  1836.0  08087000800  40.152142    314014.0    8.0      8.00
# 12657  1900.0  13269950301  32.499910   1792585.0   13.0   9503.01
# 12658  3746.0  42043020100  40.257994   2287145.0   42.0    201.00
# 12659  1134.0  12105016100  27.746262  80407214.0   12.0    161.00
# 12660  4156.0  16083001600  42.308988   9856292.0   16.0     16.00
#
#                 OID LSADC FUNCSTAT   INTPTLAT  ...     CENTLON   HU100  \
# 0      2.079074e+13    CT        S  42.881277  ...  -73.913102  1320.0
# 1      2.079021e+13    CT        S  41.858697  ...  -70.744259  2689.0
# 2      2.079026e+13    CT        S  42.120093  ...  -71.205044  2145.0
# 3      2.079023e+13    CT        S  41.633184  ...  -71.517378  2301.0
# 4      2.079031e+13    CT        S  40.563551  ...  -74.571689  2702.0
# ...             ...   ...      ...        ...  ...         ...     ...
# 12656  2.079036e+13    CT        S  40.154192  ... -103.615312   793.0
# 12657  2.079015e+15    CT        S  32.485892  ...  -84.326620  1031.0
# 12658  2.079047e+13    CT        S  40.257558  ...  -76.884192  2764.0
# 12659  2.079037e+13    CT        S  27.745906  ...  -81.973661   482.0
# 12660  2.079015e+15    CT        S  42.306243  ... -114.675063  1553.0
#
#            AREALAND    INTPTLON  MTFCC  UR  COUNTY error lat  lng
# 0      7.206301e+06  -73.911677  G5020   M    93.0   NaN NaN  NaN
# 1      6.948583e+07  -70.745874  G5020   M    23.0   NaN NaN  NaN
# 2      2.839787e+07  -71.203693  G5020   M    21.0   NaN NaN  NaN
# 3      3.166488e+07  -71.524229  G5020   M     3.0   NaN NaN  NaN
# 4      1.127632e+07  -74.570409  G5020   U    35.0   NaN NaN  NaN
# ...             ...         ...    ...  ..     ...   ...  ..  ...
# 12656  8.739758e+08 -103.651230  G5020   M    87.0   NaN NaN  NaN
# 12657  3.932802e+08  -84.327847  G5020   R   269.0   NaN NaN  NaN
# 12658  2.290375e+06  -76.881726  G5020   U    43.0   NaN NaN  NaN
# 12659  2.774396e+08  -81.978291  G5020   R   105.0   NaN NaN  NaN
# 12660  4.059031e+09 -114.670262  G5020   R    83.0   NaN NaN  NaN
#
# [12661 rows x 23 columns]

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT']
census_geos_df = census_geos[to_keep]
census_geos_df
# Out:
#              GEOID  STATE  COUNTY     TRACT
# 0      36093032502   36.0    93.0   32502.0
# 1      25023544200   25.0    23.0  544200.0
# 2      25021414100   25.0    21.0  414100.0
# 3      44003020903   44.0     3.0   20903.0
# 4      34035051000   34.0    35.0   51000.0
# ...            ...    ...     ...       ...
# 12656  08087000800    8.0    87.0     800.0
# 12657  13269950301   13.0   269.0  950301.0
# 12658  42043020100   42.0    43.0   20100.0
# 12659  12105016100   12.0   105.0   16100.0
# 12660  16083001600   16.0    83.0    1600.0
#
# [12661 rows x 4 columns]

# %%
df_with_geos = pd.concat(
    [ 
        df.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()
# Out:
#    Unnamed: 0                      plant_name  Plant Code State  Sector Name  \
# 0           0          (3K) 59 Hetcheltown Rd       66729    NY  IPP Non-CHP
# 1           1                0 Hammond St CSG       64876    MA  IPP Non-CHP
# 2           2                    1 Commercial       67464    MA  IPP Non-CHP
# 3           3  10 Briggs Solar NG, LLC (East)       62781    RI  IPP Non-CHP
# 4           4   10 Finderne Avenue Solar, LLC       64023    NJ  IPP Non-CHP
#
#   Prime Movers Fuel Types  Primary Technology  \
# 0           PV        SUN  Solar Photovoltaic
# 1       BA, PV   MWH, SUN            Multiple
# 2       BA, PV   MWH, SUN            Multiple
# 3           PV        SUN  Solar Photovoltaic
# 4           PV        SUN  Solar Photovoltaic
#
#   withdrawal_volume_million_gallons discharge_volume_million_gallons  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   consumption_volume_million_gallons           energy_category  \
# 0                                NaN  Renewable Energy Sources
# 1                                NaN                     Other
# 2                                NaN                     Other
# 3                                NaN  Renewable Energy Sources
# 4                                NaN  Renewable Energy Sources
#
#                                     map_link  longitude   latitude  \
# 0    map/?center=-73.91048,42.87657&level=14 -73.910480  42.876570
# 1  map/?center=-70.726675,41.808547&level=14 -70.726675  41.808547
# 2        map/?center=-71.237,42.115&level=14 -71.237000  42.115000
# 3    map/?center=-71.49625,41.63269&level=14 -71.496250  41.632690
# 4    map/?center=-74.57594,40.55812&level=14 -74.575940  40.558120
#
#          GEOID  STATE  COUNTY     TRACT
# 0  36093032502   36.0    93.0   32502.0
# 1  25023544200   25.0    23.0  544200.0
# 2  25021414100   25.0    21.0  414100.0
# 3  44003020903   44.0     3.0   20903.0
# 4  34035051000   34.0    35.0   51000.0

# %%
df_with_geos.tail()
# Out:
#        Unnamed: 0                 plant_name  Plant Code State  \
# 12656       12656                     Pawnee        6248    CO
# 12657       12657         Pawpaw Solar Plant       59894    GA
# 12658       12658  Paxton Creek Cogeneration       50373    PA
# 12659       12659          Payne Creek Solar       61665    FL
# 12660       12660              Payne's Ferry       57124    ID
#
#             Sector Name Prime Movers Fuel Types  \
# 12656  Electric Utility           ST        SUB
# 12657       IPP Non-CHP           PV        SUN
# 12658           IPP CHP           IC         NG
# 12659  Electric Utility           PV        SUN
# 12660       IPP Non-CHP           WT        WND
#
#                            Primary Technology  \
# 12656                 Conventional Steam Coal
# 12657                      Solar Photovoltaic
# 12658  Natural Gas Internal Combustion Engine
# 12659                      Solar Photovoltaic
# 12660                    Onshore Wind Turbine
#
#       withdrawal_volume_million_gallons discharge_volume_million_gallons  \
# 12656                              1970                                0
# 12657                               NaN                              NaN
# 12658                               NaN                              NaN
# 12659                               NaN                              NaN
# 12660                               NaN                              NaN
#
#       consumption_volume_million_gallons           energy_category  \
# 12656                               1970                      Coal
# 12657                                NaN  Renewable Energy Sources
# 12658                                NaN               Natural Gas
# 12659                                NaN  Renewable Energy Sources
# 12660                                NaN  Renewable Energy Sources
#
#                                          map_link   longitude   latitude  \
# 12656      map/?center=-103.6803,40.2217&level=14 -103.680300  40.221700
# 12657   map/?center=-84.256778,32.572875&level=14  -84.256778  32.572875
# 12658       map/?center=-76.8771,40.2653&level=14  -76.877100  40.265300
# 12659   map/?center=-81.964222,27.664583&level=14  -81.964222  27.664583
# 12660  map/?center=-115.010833,42.825278&level=14 -115.010833  42.825278
#
#              GEOID  STATE  COUNTY     TRACT
# 12656  08087000800    8.0    87.0     800.0
# 12657  13269950301   13.0   269.0  950301.0
# 12658  42043020100   42.0    43.0   20100.0
# 12659  12105016100   12.0   105.0   16100.0
# 12660  16083001600   16.0    83.0    1600.0

# %%
df_with_geos.shape
# Out:
# (12661, 19)

# %%
df_with_geos[df_with_geos['GEOID'] == '06029006012']
# Out:
#        Unnamed: 0                         plant_name  Plant Code State  \
# 90             90                               85 A       52162    CA
# 91             91                               85 B       52163    CA
# 378           378          Alta Wind Energy Center I       57282    CA
# 379           379         Alta Wind Energy Center II       57291    CA
# 380           380        Alta Wind Energy Center III       57292    CA
# 385           385                       Alta Wind XI       58395    CA
# 1797         1797  CTV Power Purchase Contract Trust       54300    CA
# 1879         1879                  Cameron Ridge LLC       10586    CA
# 2569         2569                   Coram Energy LLC       54299    CA
# 2570         2570             Coram Energy LLC (ECT)       54298    CA
# 2571         2571                    Coram Tehachapi       54750    CA
# 5013         5013            Helzel & Schwarzhoff 86       56275    CA
# 6597         6597                   Manzana Wind LLC       57484    CA
# 7063         7063                    Mojave 16/17/18       50821    CA
# 7064         7064               Mojave 16/17/18 BESS       67093    CA
# 7065         7065                       Mojave 3/4/5       52142    CA
# 7298         7298                  Mustang Hills LLC       57833    CA
# 7820         7820         Oak Creek Energy Systems I       50754    CA
# 7860         7860                         Oasis Alta       63941    CA
# 7861         7861                         Oasis Wind       56302    CA
# 8519         8519                         Point Wind       63482    CA
# 9039         9039                           Ridgetop       54931    CA
# 9040         9040                Ridgetop Energy LLC       10597    CA
# 9072         9072              Rising Tree Wind Farm       57621    CA
# 9073         9073           Rising Tree Wind Farm II       59235    CA
# 9074         9074          Rising Tree Wind Farm III       59236    CA
# 9363         9363                   SEPV Mojave West       59740    CA
# 9491         9491                      Sagebrush ESS       65933    CA
# 10721       10721                  TPC Windfarms LLC       54647    CA
# 10813       10813          Tehachapi Wind Resource I       10191    CA
# 11508       11508         Victory Garden (Tehachapi)       50532    CA
# 11552       11552                     Voyager Wind I       60594    CA
# 11553       11553                    Voyager Wind II       61582    CA
# 11554       11554                   Voyager Wind III       61583    CA
# 11555       11555                    Voyager Wind IV       61584    CA
# 12281       12281                Windhub Solar A LLC       59878    CA
# 12288       12288                         Windstar 1       57774    CA
# 12457       12457                                ZCO       56276    CA
#
#        Sector Name Prime Movers Fuel Types    Primary Technology  \
# 90     IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 91     IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 378    IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 379    IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 380    IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 385    IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 1797   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 1879   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 2569   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 2570   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 2571   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 5013   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 6597   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7063   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7064   IPP Non-CHP           BA        MWH             Batteries
# 7065   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7298   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7820   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7860   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 7861   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 8519   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9039   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9040   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9072   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9073   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9074   IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 9363   IPP Non-CHP           PV        SUN    Solar Photovoltaic
# 9491   IPP Non-CHP           BA        MWH             Batteries
# 10721  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 10813  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 11508  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 11552  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 11553  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 11554  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 11555  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 12281  IPP Non-CHP           PV        SUN    Solar Photovoltaic
# 12288  IPP Non-CHP           WT        WND  Onshore Wind Turbine
# 12457  IPP Non-CHP           WT        WND  Onshore Wind Turbine
#
#       withdrawal_volume_million_gallons discharge_volume_million_gallons  \
# 90                                  NaN                              NaN
# 91                                  NaN                              NaN
# 378                                 NaN                              NaN
# 379                                 NaN                              NaN
# 380                                 NaN                              NaN
# 385                                 NaN                              NaN
# 1797                                NaN                              NaN
# 1879                                NaN                              NaN
# 2569                                NaN                              NaN
# 2570                                NaN                              NaN
# 2571                                NaN                              NaN
# 5013                                NaN                              NaN
# 6597                                NaN                              NaN
# 7063                                NaN                              NaN
# 7064                                NaN                              NaN
# 7065                                NaN                              NaN
# 7298                                NaN                              NaN
# 7820                                NaN                              NaN
# 7860                                NaN                              NaN
# 7861                                NaN                              NaN
# 8519                                NaN                              NaN
# 9039                                NaN                              NaN
# 9040                                NaN                              NaN
# 9072                                NaN                              NaN
# 9073                                NaN                              NaN
# 9074                                NaN                              NaN
# 9363                                NaN                              NaN
# 9491                                NaN                              NaN
# 10721                               NaN                              NaN
# 10813                               NaN                              NaN
# 11508                               NaN                              NaN
# 11552                               NaN                              NaN
# 11553                               NaN                              NaN
# 11554                               NaN                              NaN
# 11555                               NaN                              NaN
# 12281                               NaN                              NaN
# 12288                               NaN                              NaN
# 12457                               NaN                              NaN
#
#       consumption_volume_million_gallons           energy_category  \
# 90                                   NaN  Renewable Energy Sources
# 91                                   NaN  Renewable Energy Sources
# 378                                  NaN  Renewable Energy Sources
# 379                                  NaN  Renewable Energy Sources
# 380                                  NaN  Renewable Energy Sources
# 385                                  NaN  Renewable Energy Sources
# 1797                                 NaN  Renewable Energy Sources
# 1879                                 NaN  Renewable Energy Sources
# 2569                                 NaN  Renewable Energy Sources
# 2570                                 NaN  Renewable Energy Sources
# 2571                                 NaN  Renewable Energy Sources
# 5013                                 NaN  Renewable Energy Sources
# 6597                                 NaN  Renewable Energy Sources
# 7063                                 NaN  Renewable Energy Sources
# 7064                                 NaN                     Other
# 7065                                 NaN  Renewable Energy Sources
# 7298                                 NaN  Renewable Energy Sources
# 7820                                 NaN  Renewable Energy Sources
# 7860                                 NaN  Renewable Energy Sources
# 7861                                 NaN  Renewable Energy Sources
# 8519                                 NaN  Renewable Energy Sources
# 9039                                 NaN  Renewable Energy Sources
# 9040                                 NaN  Renewable Energy Sources
# 9072                                 NaN  Renewable Energy Sources
# 9073                                 NaN  Renewable Energy Sources
# 9074                                 NaN  Renewable Energy Sources
# 9363                                 NaN  Renewable Energy Sources
# 9491                                 NaN                     Other
# 10721                                NaN  Renewable Energy Sources
# 10813                                NaN  Renewable Energy Sources
# 11508                                NaN  Renewable Energy Sources
# 11552                                NaN  Renewable Energy Sources
# 11553                                NaN  Renewable Energy Sources
# 11554                                NaN  Renewable Energy Sources
# 11555                                NaN  Renewable Energy Sources
# 12281                                NaN  Renewable Energy Sources
# 12288                                NaN  Renewable Energy Sources
# 12457                                NaN  Renewable Energy Sources
#
#                                          map_link   longitude   latitude  \
# 90     map/?center=-118.324772,35.095797&level=14 -118.324772  35.095797
# 91     map/?center=-118.332533,35.102577&level=14 -118.332533  35.102577
# 378    map/?center=-118.353422,35.033725&level=14 -118.353422  35.033725
# 379    map/?center=-118.295278,35.023889&level=14 -118.295278  35.023889
# 380    map/?center=-118.295278,35.023889&level=14 -118.295278  35.023889
# 385           map/?center=-118.39,35.065&level=14 -118.390000  35.065000
# 1797       map/?center=-118.3083,35.0583&level=14 -118.308300  35.058300
# 1879        map/?center=-118.3158,35.075&level=14 -118.315800  35.075000
# 2569        map/?center=-118.3417,35.075&level=14 -118.341700  35.075000
# 2570       map/?center=-118.3417,35.0583&level=14 -118.341700  35.058300
# 2571     map/?center=-118.339444,35.0663&level=14 -118.339444  35.066300
# 5013       map/?center=-118.3952,35.0925&level=14 -118.395200  35.092500
# 6597       map/?center=-118.4612,34.9349&level=14 -118.461200  34.934900
# 7063        map/?center=-118.2642,35.045&level=14 -118.264200  35.045000
# 7064   map/?center=-118.275556,35.044166&level=14 -118.275556  35.044166
# 7065       map/?center=-118.2572,35.0506&level=14 -118.257200  35.050600
# 7298   map/?center=-118.293188,35.030855&level=14 -118.293188  35.030855
# 7820   map/?center=-118.276388,35.043889&level=14 -118.276388  35.043889
# 7860   map/?center=-118.291944,35.059166&level=14 -118.291944  35.059166
# 7861    map/?center=-118.292406,35.06094&level=14 -118.292406  35.060940
# 8519   map/?center=-118.361389,35.080833&level=14 -118.361389  35.080833
# 9039        map/?center=-118.3153,35.074&level=14 -118.315300  35.074000
# 9040       map/?center=-118.3167,35.0697&level=14 -118.316700  35.069700
# 9072     map/?center=-118.218333,35.0775&level=14 -118.218333  35.077500
# 9073   map/?center=-118.206389,35.088889&level=14 -118.206389  35.088889
# 9074   map/?center=-118.243333,35.060556&level=14 -118.243333  35.060556
# 9363   map/?center=-118.282694,35.022903&level=14 -118.282694  35.022903
# 9491       map/?center=-118.2628,35.0477&level=14 -118.262800  35.047700
# 10721        map/?center=-118.2572,35.05&level=14 -118.257200  35.050000
# 10813  map/?center=-118.389722,35.060556&level=14 -118.389722  35.060556
# 11508      map/?center=-118.3833,35.0686&level=14 -118.383300  35.068600
# 11552   map/?center=-118.28273,35.046061&level=14 -118.282730  35.046061
# 11553  map/?center=-118.268616,35.073377&level=14 -118.268616  35.073377
# 11554  map/?center=-118.264734,35.060768&level=14 -118.264734  35.060768
# 11555    map/?center=-118.2497,35.077872&level=14 -118.249700  35.077872
# 12281      map/?center=-118.2879,35.0199&level=14 -118.287900  35.019900
# 12288  map/?center=-118.354722,35.054167&level=14 -118.354722  35.054167
# 12457      map/?center=-118.3811,35.0772&level=14 -118.381100  35.077200
#
#              GEOID  STATE  COUNTY   TRACT
# 90     06029006012    6.0    29.0  6012.0
# 91     06029006012    6.0    29.0  6012.0
# 378    06029006012    6.0    29.0  6012.0
# 379    06029006012    6.0    29.0  6012.0
# 380    06029006012    6.0    29.0  6012.0
# 385    06029006012    6.0    29.0  6012.0
# 1797   06029006012    6.0    29.0  6012.0
# 1879   06029006012    6.0    29.0  6012.0
# 2569   06029006012    6.0    29.0  6012.0
# 2570   06029006012    6.0    29.0  6012.0
# 2571   06029006012    6.0    29.0  6012.0
# 5013   06029006012    6.0    29.0  6012.0
# 6597   06029006012    6.0    29.0  6012.0
# 7063   06029006012    6.0    29.0  6012.0
# 7064   06029006012    6.0    29.0  6012.0
# 7065   06029006012    6.0    29.0  6012.0
# 7298   06029006012    6.0    29.0  6012.0
# 7820   06029006012    6.0    29.0  6012.0
# 7860   06029006012    6.0    29.0  6012.0
# 7861   06029006012    6.0    29.0  6012.0
# 8519   06029006012    6.0    29.0  6012.0
# 9039   06029006012    6.0    29.0  6012.0
# 9040   06029006012    6.0    29.0  6012.0
# 9072   06029006012    6.0    29.0  6012.0
# 9073   06029006012    6.0    29.0  6012.0
# 9074   06029006012    6.0    29.0  6012.0
# 9363   06029006012    6.0    29.0  6012.0
# 9491   06029006012    6.0    29.0  6012.0
# 10721  06029006012    6.0    29.0  6012.0
# 10813  06029006012    6.0    29.0  6012.0
# 11508  06029006012    6.0    29.0  6012.0
# 11552  06029006012    6.0    29.0  6012.0
# 11553  06029006012    6.0    29.0  6012.0
# 11554  06029006012    6.0    29.0  6012.0
# 11555  06029006012    6.0    29.0  6012.0
# 12281  06029006012    6.0    29.0  6012.0
# 12288  06029006012    6.0    29.0  6012.0
# 12457  06029006012    6.0    29.0  6012.0

# %%
df_with_geos['plant_name'].nunique()
# Out:
# 12633

# %%
df_with_geos.to_csv('plants_with_geos.csv')

# %%
df_grants = pd.read_csv('US Environmental Protection Agency Environmental Justice Grants - Data.csv')

# %%
df_grants.head()
# Out:
#                                    Announcement Date  \
# 0  Date of announcement (for data on projects in ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  Award Date  \
# 0  Date of award or rebate.
# 1                05-31-2023
# 2                01-07-2025
# 3                07-10-2024
# 4                07-19-2023
#
#                                        Project Title  \
# 0                  Descriptive title of the project.
# 1                               Morrisonville CUSD 1
# 2  Saint Paul Island Renewable Energy Integration...
# 3  Cleanup Cooperative Agreement for City of West...
# 4  Inflation Reduction Act &ndash; Climate Pollut...
#
#                                  Project Description  \
# 0                  Brief description of the project.
# 1  With funding from the Bipartisan Infrastructur...
# 2  The purpose of this award is to provide fundin...
# 3  Brownfields are real property, the expansion, ...
# 4  The purpose of this grant agreement is to prov...
#
#                               Recipient  \
# 0       Name of recipient of the award.
# 1                  Morrisonville Cusd 1
# 2  Aleut Community of Saint Paul Island
# 3                     CITY OF WESTBROOK
# 4          Sacramento Metropolitan AQMD
#
#                                       Funding Source  \
# 0  Bipartisan Infrastructure Law (BIL) or Inflati...
# 1                                                BIL
# 2                                                IRA
# 3                                                BIL
# 4                                                IRA
#
#                                     Type of Award        Funding Status  \
# 0  Identifies if a grant is primary or sub-award.  Selected or Awarded.
# 1                                         Primary               Awarded
# 2                                         Primary               Awarded
# 3                                         Primary               Awarded
# 4                                         Primary               Awarded
#
#            Federal Award Identification Number  \
# 0  Federal Award Identification Number (FAIN).
# 1                                          NaN
# 2                                     84105401
# 3                                     00A01199
# 4                                     98T74301
#
#                                 Award Amount  ...  \
# 0  Funds (dollars) received from BIL or IRA.  ...
# 1                                    790,000  ...
# 2                                 14,820,331  ...
# 3                                  4,000,000  ...
# 4                                  1,000,000  ...
#
#                                           Zip Code  \
# 0  Zip code of award/project place of performance.
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                                           City  \
# 0  City of award/project place of performance.
# 1                                          NaN
# 2                                      St Paul
# 3                                    Westbrook
# 4                                          NaN
#
#                                           County  \
# 0  County of award/project place of performance.
# 1                                            NaN
# 2                     Aleutians West Census Area
# 3                                            NaN
# 4                              Sacramento County
#
#                                           State  \
# 0  State of award/project place of performance.
# 1                                            IL
# 2                                            AK
# 3                                            ME
# 4                                            CA
#
#                                   Assistance Listing  \
# 0  The Assistance Listing Number (formerly known ...
# 1                                                NaN
# 2                                             66.046
# 3                                             66.818
# 4                                             66.046
#
#                                              Program  \
# 0  Bipartisan Infrastructure Law or Inflation Red...
# 1                           Clean School Bus Rebates
# 2                        CPRG - Implementation Grant
# 3                               Brownfields Projects
# 4                              CPRG - Planning Grant
#
#                                  Investment Category  \
# 0  Investment category (Climate Action, Air Inves...
# 1                                    Air Investments
# 2                                     Climate Action
# 3                                   Land Investments
# 4                                     Climate Action
#
#                                          Website Url  \
# 0  URL containing more detailed information about...
# 1  https://www.epa.gov/cleanschoolbus/awarded-cle...
# 2  https://www.epa.gov/inflation-reduction-act/ab...
# 3  https://www.epa.gov/brownfields/bipartisan-inf...
# 4  https://www.epa.gov/inflation-reduction-act/ab...
#
#                                     Announcement Url     Data Extract Date
# 0  URL containing press release (announcing fundi...  Date data extracted.
# 1  https://www.epa.gov/cleanschoolbus/awarded-cle...            01-31-2025
# 2                                                NaN            01-31-2025
# 3                                                NaN            01-31-2025
# 4                                                NaN            01-31-2025
#
# [5 rows x 23 columns]

# %%
df_grants = df_grants.drop(0, axis=0).reset_index(drop=True)

# %%
df_grants.head()
# Out:
#   Announcement Date  Award Date  \
# 0               NaN  05-31-2023
# 1               NaN  01-07-2025
# 2               NaN  07-10-2024
# 3               NaN  07-19-2023
# 4               NaN  09-11-2023
#
#                                        Project Title  \
# 0                               Morrisonville CUSD 1
# 1  Saint Paul Island Renewable Energy Integration...
# 2  Cleanup Cooperative Agreement for City of West...
# 3  Inflation Reduction Act &ndash; Climate Pollut...
# 4  Large Diameter Water Main Dead Ends Eliminatio...
#
#                                  Project Description  \
# 0  With funding from the Bipartisan Infrastructur...
# 1  The purpose of this award is to provide fundin...
# 2  Brownfields are real property, the expansion, ...
# 3  The purpose of this grant agreement is to prov...
# 4  This Bipartisan Infrastructure Law (BIL) (also...
#
#                               Recipient Funding Source Type of Award  \
# 0                  Morrisonville Cusd 1            BIL       Primary
# 1  Aleut Community of Saint Paul Island            IRA       Primary
# 2                     CITY OF WESTBROOK            BIL       Primary
# 3          Sacramento Metropolitan AQMD            IRA       Primary
# 4          DC Water and Sewer Authority            BIL       Primary
#
#   Funding Status Federal Award Identification Number      Award Amount  ...  \
# 0        Awarded                                 NaN           790,000  ...
# 1        Awarded                            84105401        14,820,331  ...
# 2        Awarded                            00A01199         4,000,000  ...
# 3        Awarded                            98T74301         1,000,000  ...
# 4        Awarded                            95328501         5,133,600  ...
#
#   Zip Code       City                      County State Assistance Listing  \
# 0      NaN        NaN                         NaN    IL                NaN
# 1      NaN    St Paul  Aleutians West Census Area    AK             66.046
# 2      NaN  Westbrook                         NaN    ME             66.818
# 3      NaN        NaN           Sacramento County    CA             66.046
# 4      NaN        NaN                         NaN    DC             66.468
#
#                                Program Investment Category  \
# 0             Clean School Bus Rebates     Air Investments
# 1          CPRG - Implementation Grant      Climate Action
# 2                 Brownfields Projects    Land Investments
# 3                CPRG - Planning Grant      Climate Action
# 4  Drinking Water State Revolving Fund   Water Investments
#
#                                          Website Url  \
# 0  https://www.epa.gov/cleanschoolbus/awarded-cle...
# 1  https://www.epa.gov/inflation-reduction-act/ab...
# 2  https://www.epa.gov/brownfields/bipartisan-inf...
# 3  https://www.epa.gov/inflation-reduction-act/ab...
# 4                          https://www.epa.gov/dwsrf
#
#                                     Announcement Url Data Extract Date
# 0  https://www.epa.gov/cleanschoolbus/awarded-cle...        01-31-2025
# 1                                                NaN        01-31-2025
# 2                                                NaN        01-31-2025
# 3                                                NaN        01-31-2025
# 4                                                NaN        01-31-2025
#
# [5 rows x 23 columns]

# %%
import pandas as pd
import requests_cache
import time
import os
from tqdm import tqdm

# Enable caching to speed up repeated requests
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng, retries=3, delay=1):
    url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
    params = {
        "x": lng,
        "y": lat,
        "benchmark": "Public_AR_Census2020",
        "vintage": "Census2020_Census2020",
        "format": "json"
    }
    for attempt in range(retries):
        try:
            response = cache.get(url, params=params, timeout=10)
            response.raise_for_status()
            data = response.json()
            tract = data['result']['geographies']['Census Tracts'][0]
            return tract
        except Exception as e:
            if attempt < retries - 1:
                time.sleep(delay * (attempt + 1))  # Exponential backoff
            else:
                return {"error": str(e), "lat": lat, "lng": lng}

def process_chunk(chunk, chunk_index, save_prefix="census_geos_part"):
    results = []
    for _, row in tqdm(chunk.iterrows(), total=len(chunk), desc=f"Processing chunk {chunk_index + 1}"):
        lat, lng = row['Latitude'], row['Longitude']
        result = geocode(lat, lng)
        results.append(result)

    # Convert the results into a DataFrame
    df_chunk = pd.DataFrame(results)
    output_path = f"{save_prefix}_{chunk_index + 1}.csv"
    df_chunk.to_csv(output_path, index=False)

    # Free memory by deleting intermediate data
    del results, df_chunk  
    return output_path

def geocode_in_chunks_safe(df, chunk_size=500, save_prefix="grants_geos_part"):
    total_chunks = (len(df) + chunk_size - 1) // chunk_size  # Calculate number of chunks
    
    for i in range(total_chunks):
        output_file = f"{save_prefix}_{i + 1}.csv"
        print(f"Processing chunk {i + 1} of {total_chunks}")
        
        # Skip checking if file exists; process each chunk regardless
        chunk = df.iloc[i*chunk_size : (i+1)*chunk_size]  # Select the chunk
        process_chunk(chunk, i, save_prefix=save_prefix)
        time.sleep(2)  # Sleep between requests to avoid hitting API rate limits

# Now, run this on your DataFrame
geocode_in_chunks_safe(df_grants)
# Out:
# Processing chunk 1 of 11
# Processing chunk 1: 100%|█| 500/500 [00:03<00:00, 126.25it/s
# Processing chunk 2 of 11
# Processing chunk 2: 100%|█| 500/500 [00:00<00:00, 954.09it/s
# Processing chunk 3 of 11
# Processing chunk 3: 100%|█| 500/500 [00:00<00:00, 940.66it/s
# Processing chunk 4 of 11
# Processing chunk 4: 100%|█| 500/500 [00:00<00:00, 880.27it/s
# Processing chunk 5 of 11
# Processing chunk 5: 100%|█| 500/500 [00:00<00:00, 903.77it/s
# Processing chunk 6 of 11
# Processing chunk 6: 100%|█| 500/500 [00:00<00:00, 903.81it/s
# Processing chunk 7 of 11
# Processing chunk 7: 100%|█| 500/500 [00:01<00:00, 496.90it/s
# Processing chunk 8 of 11
# Processing chunk 8: 100%|█| 500/500 [00:00<00:00, 879.07it/s
# Processing chunk 9 of 11
# Processing chunk 9: 100%|█| 500/500 [00:00<00:00, 757.50it/s
# Processing chunk 10 of 11
# Processing chunk 10: 100%|█| 500/500 [00:00<00:00, 1069.83it
# Processing chunk 11 of 11
# Processing chunk 11: 100%|█| 226/226 [00:00<00:00, 906.61it/

# %%
import glob

# Adjust this pattern to match your saved files
chunk_files = sorted(glob.glob("grants_geos_part_*.csv"))

# Load and concatenate them
grants_df = pd.concat([pd.read_csv(f) for f in chunk_files], ignore_index=True)

# Optional: Save combined result to disk
grants_df.to_csv("grants_geocoded_full.csv", index=False)

# Check it out
grants_df.head()
# Out:
#                                                error  \
# 0  400 Client Error:  for url: https://geocoding....
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                lat  \
# 0  Latitude of award/project place of performance.
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                                                 lng  POP100         GEOID  \
# 0  Longitude of award/project place of performance.     NaN           NaN
# 1                                               NaN  4796.0  1.702196e+10
# 2                                               NaN   978.0  2.016000e+09
# 3                                               NaN  5175.0  2.300500e+10
# 4                                               NaN  1609.0  6.067009e+09
#
#      CENTLAT     AREAWATER  STATE  BASENAME           OID  ...  \
# 0        NaN           NaN    NaN       NaN           NaN  ...
# 1  39.441237  4.022030e+06   17.0   9590.00  2.079015e+13  ...
# 2  52.593343  2.207908e+10    2.0      1.00  2.079045e+12  ...
# 3  43.710389  1.286170e+05   23.0     27.00  2.079020e+13  ...
# 4  38.438152  0.000000e+00    6.0     93.32  2.079037e+14  ...
#
#                  NAME OBJECTID     TRACT     CENTLON   HU100      AREALAND  \
# 0                 NaN      NaN       NaN         NaN     NaN           NaN
# 1   Census Tract 9590  83511.0  959000.0  -89.387215  2119.0  4.910069e+08
# 2      Census Tract 1  17011.0     100.0 -176.454970   555.0  8.556804e+09
# 3     Census Tract 27  48443.0    2700.0  -70.362032  2289.0  1.271936e+07
# 4  Census Tract 93.32  66858.0    9332.0 -121.339287   498.0  7.870005e+06
#
#      INTPTLON  MTFCC   UR  COUNTY
# 0         NaN    NaN  NaN     NaN
# 1  -89.388553  G5020    M    21.0
# 2  178.338813  G5020    R    16.0
# 3  -70.365230  G5020    M     5.0
# 4 -121.339287  G5020    M    67.0
#
# [5 rows x 23 columns]

# %%
grants_df['GEOID'] = grants_df['GEOID'].apply(
    lambda x: str(int(float(x))).zfill(11) if pd.notnull(x) else x
)

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT']
grants_geos_df = grants_df[to_keep]
grants_geos_df
# Out:
#             GEOID  STATE  COUNTY     TRACT
# 0             NaN    NaN     NaN       NaN
# 1     17021959000   17.0    21.0  959000.0
# 2     02016000100    2.0    16.0     100.0
# 3     23005002700   23.0     5.0    2700.0
# 4     06067009332    6.0    67.0    9332.0
# ...           ...    ...     ...       ...
# 5221  04001944301    4.0     1.0  944301.0
# 5222  72107955001   72.0   107.0  955001.0
# 5223  17201004004   17.0   201.0    4004.0
# 5224  27035951100   27.0    35.0  951100.0
# 5225  55025991702   55.0    25.0  991702.0
#
# [5226 rows x 4 columns]

# %%
grants_with_geos = pd.concat(
    [ 
        df_grants.reset_index(drop=True),
        grants_geos_df.reset_index(drop=True)
    ], 
    axis=1)

grants_with_geos.head()
# Out:
#                                    Announcement Date  \
# 0  Date of announcement (for data on projects in ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  Award Date  \
# 0  Date of award or rebate.
# 1                05-31-2023
# 2                01-07-2025
# 3                07-10-2024
# 4                07-19-2023
#
#                                        Project Title  \
# 0                  Descriptive title of the project.
# 1                               Morrisonville CUSD 1
# 2  Saint Paul Island Renewable Energy Integration...
# 3  Cleanup Cooperative Agreement for City of West...
# 4  Inflation Reduction Act &ndash; Climate Pollut...
#
#                                  Project Description  \
# 0                  Brief description of the project.
# 1  With funding from the Bipartisan Infrastructur...
# 2  The purpose of this award is to provide fundin...
# 3  Brownfields are real property, the expansion, ...
# 4  The purpose of this grant agreement is to prov...
#
#                               Recipient  \
# 0       Name of recipient of the award.
# 1                  Morrisonville Cusd 1
# 2  Aleut Community of Saint Paul Island
# 3                     CITY OF WESTBROOK
# 4          Sacramento Metropolitan AQMD
#
#                                       Funding Source  \
# 0  Bipartisan Infrastructure Law (BIL) or Inflati...
# 1                                                BIL
# 2                                                IRA
# 3                                                BIL
# 4                                                IRA
#
#                                     Type of Award        Funding Status  \
# 0  Identifies if a grant is primary or sub-award.  Selected or Awarded.
# 1                                         Primary               Awarded
# 2                                         Primary               Awarded
# 3                                         Primary               Awarded
# 4                                         Primary               Awarded
#
#            Federal Award Identification Number  \
# 0  Federal Award Identification Number (FAIN).
# 1                                          NaN
# 2                                     84105401
# 3                                     00A01199
# 4                                     98T74301
#
#                                 Award Amount  ...  \
# 0  Funds (dollars) received from BIL or IRA.  ...
# 1                                    790,000  ...
# 2                                 14,820,331  ...
# 3                                  4,000,000  ...
# 4                                  1,000,000  ...
#
#                                   Assistance Listing  \
# 0  The Assistance Listing Number (formerly known ...
# 1                                                NaN
# 2                                             66.046
# 3                                             66.818
# 4                                             66.046
#
#                                              Program  \
# 0  Bipartisan Infrastructure Law or Inflation Red...
# 1                           Clean School Bus Rebates
# 2                        CPRG - Implementation Grant
# 3                               Brownfields Projects
# 4                              CPRG - Planning Grant
#
#                                  Investment Category  \
# 0  Investment category (Climate Action, Air Inves...
# 1                                    Air Investments
# 2                                     Climate Action
# 3                                   Land Investments
# 4                                     Climate Action
#
#                                          Website Url  \
# 0  URL containing more detailed information about...
# 1  https://www.epa.gov/cleanschoolbus/awarded-cle...
# 2  https://www.epa.gov/inflation-reduction-act/ab...
# 3  https://www.epa.gov/brownfields/bipartisan-inf...
# 4  https://www.epa.gov/inflation-reduction-act/ab...
#
#                                     Announcement Url     Data Extract Date  \
# 0  URL containing press release (announcing fundi...  Date data extracted.
# 1  https://www.epa.gov/cleanschoolbus/awarded-cle...            01-31-2025
# 2                                                NaN            01-31-2025
# 3                                                NaN            01-31-2025
# 4                                                NaN            01-31-2025
#
#          GEOID STATE COUNTY     TRACT
# 0          NaN   NaN    NaN       NaN
# 1  17021959000  17.0   21.0  959000.0
# 2  02016000100   2.0   16.0     100.0
# 3  23005002700  23.0    5.0    2700.0
# 4  06067009332   6.0   67.0    9332.0
#
# [5 rows x 27 columns]

# %%
grants_with_geos.to_csv('grants_with_geos.csv')

# %%
df_proposed = pd.read_csv('maryland_possible_locations.csv')

# %%
df_proposed.head()
# Out:
#            County District     Power Plant  \
# 0      ALLEGHENY        1C     Warrior Run
# 1      ALLEGHENY        1A       Luke Mill
# 2    ANNE ARUNDEL       31  Brandon Shores
# 3    ANNE ARUNDEL       31  Herbert Wagner
# 4  BALTIMORE CITY       7A     C.P. Crane
#
#                                      Owner  \
# 0         AES Warrior Run Ltd. Partnership
# 1                            New Page Corp
# 2  Talen Energy (Raven Power Holdings LLC)
# 3  Talen Energy (Raven Power Holdings LLC)
# 4                     Avenue Capital Group
#
#   Description (note: current gas sites may not be eligiblefor new gas if there is no GHG reduction, but could become nuclear sites)  \
# 0  180 MW, coal fired steam boiler, closed June o...
# 1    ~60 MW, 2 coal fired steam boilers, Closed 2019
# 2  1,273 MW, 2 units, coal and steam boilers, sch...
# 3  975.9 MW total (Unit 1 – Gas, Unit 2 - coal 13...
# 4  400 MW, coal; closed 2018, demolished 2022, un...
#
#     Latitude  Longitude
# 0  39.597398 -78.744465
# 1  39.474072 -79.055827
# 2  39.179750 -76.536705
# 3  39.178669 -76.526322
# 4  39.325291 -76.366534

# %%
import pandas as pd
import requests_cache
import time
from tqdm import tqdm

# Enable caching to speed up repeated requests
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng, retries=3, delay=1):
    url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
    params = {
        "x": lng,
        "y": lat,
        "benchmark": "Public_AR_Census2020",
        "vintage": "Census2020_Census2020",
        "format": "json"
    }
    for attempt in range(retries):
        try:
            response = cache.get(url, params=params, timeout=10)
            response.raise_for_status()
            data = response.json()
            tract = data['result']['geographies']['Census Tracts'][0]
            return tract
        except Exception as e:
            if attempt < retries - 1:
                time.sleep(delay * (attempt + 1))  # Exponential backoff
            else:
                return {"error": str(e), "lat": lat, "lng": lng}

def geocode_all(df_proposed, save_path="census_geos_all.csv"):
    results = []
    for _, row in tqdm(df_proposed.iterrows(), total=len(df_proposed), desc="Processing all data"):
        lat, lng = row['Latitude'], row['Longitude']
        result = geocode(lat, lng)
        results.append(result)

    # Convert the results into a DataFrame
    df_results = pd.DataFrame(results)
    df_results.to_csv(save_path, index=False)

    # Free memory by deleting intermediate data
    del results, df_results  
    print(f"Results saved to {save_path}")

# Now, run this on your DataFrame
geocode_all(df_proposed)
# Out:
# Processing all data: 100%|██████████████████████| 34/34 [00:15<00:00,  2.22it/s]
# Results saved to census_geos_all.csv

# %%
census_geos = pd.read_csv('census_geos_all.csv')

# %%
census_geos.head()
# Out:
#    POP100        GEOID    CENTLAT  AREAWATER  STATE  BASENAME  \
# 0    4097  24001000200  39.625722    3080200     24      2.00
# 1    3684  24001002200  39.486235    1043712     24     22.00
# 2   12283  24003730102  39.179930    4203009     24   7301.02
# 3   12283  24003730102  39.179930    4203009     24   7301.02
# 4    4653  24005451803  39.328623    1168179     24   4518.03
#
#                 OID LSADC FUNCSTAT   INTPTLAT                  NAME  OBJECTID  \
# 0    20790762624028    CT        S  39.612313        Census Tract 2     27367
# 1    20790762624213    CT        S  39.498072       Census Tract 22     27031
# 2  2079015484997092    CT        S  39.180121  Census Tract 7301.02     29315
# 3  2079015484997092    CT        S  39.180121  Census Tract 7301.02     29315
# 4    20790271414184    CT        S  39.325194  Census Tract 4518.03     55950
#
#     TRACT    CENTLON  HU100   AREALAND   INTPTLON  MTFCC UR  COUNTY
# 0     200 -78.687833   1425  124505956 -78.703104  G5020  M       1
# 1    2200 -78.994125   1778   60150344 -78.985812  G5020  M       1
# 2  730102 -76.552462   4813   19456267 -76.556988  G5020  U       3
# 3  730102 -76.552462   4813   19456267 -76.556988  G5020  U       3
# 4  451803 -76.377431   1998    3662472 -76.372650  G5020  M       5

# %%
census_geos['GEOID'] = census_geos['GEOID'].apply(lambda x: f"{int(x):011d}" if pd.notna(x) else x)

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT']
census_geos_df = census_geos[to_keep]
census_geos_df
# Out:
#           GEOID  STATE  COUNTY   TRACT
# 0   24001000200     24       1     200
# 1   24001002200     24       1    2200
# 2   24003730102     24       3  730102
# 3   24003730102     24       3  730102
# 4   24005451803     24       5  451803
# 5   24510240100     24     510  240100
# 6   24005492600     24       5  492600
# 7   24510250301     24     510  250301
# 8   24510260404     24     510  260404
# 9   24510240400     24     510  240400
# 10  24510210100     24     510  210100
# 11  24005492700     24       5  492700
# 12  24005492700     24       5  492700
# 13  24005403702     24       5  403702
# 14  24015031400     24      15   31400
# 15  24017851200     24      17  851200
# 16  24017850904     24      17  850904
# 17  24019970100     24      19  970100
# 18  24025302400     24      25  302400
# 19  24031700500     24      31  700500
# 20  24031700728     24      31  700728
# 21  24031701211     24      31  701211
# 22  24031705000     24      31  705000
# 23  24033800607     24      33  800607
# 24  24033800900     24      33  800900
# 25  24033801003     24      33  801003
# 26  24033801003     24      33  801003
# 27  24033807000     24      33  807000
# 28  24039930500     24      39  930500
# 29  24039930800     24      39  930800
# 30  24041960300     24      41  960300
# 31  24043010802     24      43   10802
# 32  24045010300     24      45   10300
# 33  24047951000     24      47  951000

# %%
df_proposed_with_geos = pd.concat(
    [ 
        df_proposed.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_proposed_with_geos.head()
# Out:
#            County District     Power Plant  \
# 0      ALLEGHENY        1C     Warrior Run
# 1      ALLEGHENY        1A       Luke Mill
# 2    ANNE ARUNDEL       31  Brandon Shores
# 3    ANNE ARUNDEL       31  Herbert Wagner
# 4  BALTIMORE CITY       7A     C.P. Crane
#
#                                      Owner  \
# 0         AES Warrior Run Ltd. Partnership
# 1                            New Page Corp
# 2  Talen Energy (Raven Power Holdings LLC)
# 3  Talen Energy (Raven Power Holdings LLC)
# 4                     Avenue Capital Group
#
#   Description (note: current gas sites may not be eligiblefor new gas if there is no GHG reduction, but could become nuclear sites)  \
# 0  180 MW, coal fired steam boiler, closed June o...
# 1    ~60 MW, 2 coal fired steam boilers, Closed 2019
# 2  1,273 MW, 2 units, coal and steam boilers, sch...
# 3  975.9 MW total (Unit 1 – Gas, Unit 2 - coal 13...
# 4  400 MW, coal; closed 2018, demolished 2022, un...
#
#     Latitude  Longitude        GEOID  STATE  COUNTY   TRACT
# 0  39.597398 -78.744465  24001000200     24       1     200
# 1  39.474072 -79.055827  24001002200     24       1    2200
# 2  39.179750 -76.536705  24003730102     24       3  730102
# 3  39.178669 -76.526322  24003730102     24       3  730102
# 4  39.325291 -76.366534  24005451803     24       5  451803

# %%
df_proposed_with_geos.to_csv('maryland_possible_locations_geo.csv',index=False)

# %% [markdown]
# ### Step 3 | Get Census Geographies

# %%
# Code adapted from:
# https://gis.stackexchange.com/questions/363830/applying-the-censusgeocode-package-to-an-entire-dataframe-of-geocoded-data
# Defines a geocode function that accepts lat/long and spits out geographies
# The code then runs that funciton in parllel (for speed).

import pandas as pd
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

import requests_cache
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        census = data['result']['geographies']['Census Tracts'][0]
        return census
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

def bulk_geocode(latitudes, longitudes):
    """
    Geocode a list of latitudes and longitudes in parallel (for speed).
    """

    with ThreadPoolExecutor() as tpe:
        latitudes = df['latitude']
        longitudes = df['longitude']
        mapped_results = tpe.map(geocode, latitudes, longitudes)
        mapped_results = [result for result in mapped_results if result is not None]
        data = list(tqdm(mapped_results, total=len(mapped_results)))  # Use filtered results

    return pd.DataFrame(data)

census_geos_df = bulk_geocode(df['latitude'], df['longitude']) 
census_geos_df.head()
# Out:
# Error geocoding (29.449827, -101.06011): 'Census Tracts'

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT']
census_geos_df = census_geos_df[to_keep]
census_geos_df

# %%
df_with_geos = pd.concat(
    [ 
        df.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()

# %%
df_with_geos = df_with_geos.drop(columns=["Unnamed: 0"])

# %%
df_with_geos.to_csv('plants_with_geos.csv', index=False)

# %% [markdown]
# # Step 4 | Pick a geographical level and get Census data
# Do you want Census data at the state level? county? tract? block?
#
# 1. Pick a geographical level.
# 2. See `census-example.ipynb` if you want to learn how to get Census data at your desired level

# %% [markdown]
# # Hope that helps!
