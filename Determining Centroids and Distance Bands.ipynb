# %%
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
df = pd.read_csv('plants_merged_eji.csv')
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_76457/3723414161.py:1: DtypeWarning: Columns (168,179,180,181) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('plants_merged_eji.csv')

# %%
df.shape
# Out:
# (90173, 195)

# %%
df.head()
# Out:
#    STATEFP  COUNTYFP  TRACTCE             AFFGEOID         GEOID  \
# 0     10.0       1.0  40100.0  140000US10001040100  1.000104e+10
# 1     10.0       1.0  40201.0  140000US10001040201  1.000104e+10
# 2     10.0       1.0  40203.0  140000US10001040203  1.000104e+10
# 3     10.0       1.0  40204.0  140000US10001040204  1.000104e+10
# 4     10.0       1.0  40204.0  140000US10001040204  1.000104e+10
#
#      GEOID_2020     COUNTY_x StateDesc STATEABBR  \
# 0  1.000104e+10  Kent County  Delaware        DE
# 1  1.000104e+10  Kent County  Delaware        DE
# 2  1.000104e+10  Kent County  Delaware        DE
# 3  1.000104e+10  Kent County  Delaware        DE
# 4  1.000104e+10  Kent County  Delaware        DE
#
#                                      LOCATION  ...   latitude  STATE  \
# 0     Census Tract 401; Kent County; Delaware  ...  39.185680   10.0
# 1  Census Tract 402.01; Kent County; Delaware  ...        NaN    NaN
# 2  Census Tract 402.03; Kent County; Delaware  ...        NaN    NaN
# 3  Census Tract 402.04; Kent County; Delaware  ...  39.279702   10.0
# 4  Census Tract 402.04; Kent County; Delaware  ...  39.279179   10.0
#
#    COUNTY_y    TRACT  contains_energy_source  Technology_Category  \
# 0       1.0  40100.0                       1                Solar
# 1       NaN      NaN                       0                  NaN
# 2       NaN      NaN                       0                  NaN
# 3       1.0  40204.0                       1                Solar
# 4       1.0  40204.0                       1          Natural Gas
#
#    Category_Number  fossil_fuels  renewables  energy_category_numeric
# 0                1             0           1                      1.0
# 1                0             0           0                      0.0
# 2                0             0           0                      0.0
# 3                1             0           1                      1.0
# 4                2             1           0                      2.0
#
# [5 rows x 195 columns]

# %%
import numpy as np

# %%
# Only convert non-null GEOID values, leave NaNs alone
df['GEOID'] = df['GEOID'].apply(
    lambda x: str(int(x)).zfill(11) if pd.notnull(x) else np.nan
)

# %%
df.head()
# Out:
#    STATEFP  COUNTYFP  TRACTCE             AFFGEOID        GEOID    GEOID_2020  \
# 0     10.0       1.0  40100.0  140000US10001040100  10001040100  1.000104e+10
# 1     10.0       1.0  40201.0  140000US10001040201  10001040201  1.000104e+10
# 2     10.0       1.0  40203.0  140000US10001040203  10001040203  1.000104e+10
# 3     10.0       1.0  40204.0  140000US10001040204  10001040204  1.000104e+10
# 4     10.0       1.0  40204.0  140000US10001040204  10001040204  1.000104e+10
#
#       COUNTY_x StateDesc STATEABBR  \
# 0  Kent County  Delaware        DE
# 1  Kent County  Delaware        DE
# 2  Kent County  Delaware        DE
# 3  Kent County  Delaware        DE
# 4  Kent County  Delaware        DE
#
#                                      LOCATION  ...   latitude  STATE  \
# 0     Census Tract 401; Kent County; Delaware  ...  39.185680   10.0
# 1  Census Tract 402.01; Kent County; Delaware  ...        NaN    NaN
# 2  Census Tract 402.03; Kent County; Delaware  ...        NaN    NaN
# 3  Census Tract 402.04; Kent County; Delaware  ...  39.279702   10.0
# 4  Census Tract 402.04; Kent County; Delaware  ...  39.279179   10.0
#
#    COUNTY_y    TRACT  contains_energy_source  Technology_Category  \
# 0       1.0  40100.0                       1                Solar
# 1       NaN      NaN                       0                  NaN
# 2       NaN      NaN                       0                  NaN
# 3       1.0  40204.0                       1                Solar
# 4       1.0  40204.0                       1          Natural Gas
#
#    Category_Number  fossil_fuels  renewables  energy_category_numeric
# 0                1             0           1                      1.0
# 1                0             0           0                      0.0
# 2                0             0           0                      0.0
# 3                1             0           1                      1.0
# 4                2             1           0                      2.0
#
# [5 rows x 195 columns]

# %%
df.dtypes
# Out:
# STATEFP                    float64
# COUNTYFP                   float64
# TRACTCE                    float64
# AFFGEOID                    object
# GEOID                       object
#                             ...
# Technology_Category         object
# Category_Number              int64
# fossil_fuels                 int64
# renewables                   int64
# energy_category_numeric    float64
# Length: 195, dtype: object

# %%
centroids = pd.read_csv('geocorr.csv', encoding='ISO-8859-1')
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_76457/3559749476.py:1: DtypeWarning: Columns (0,1,2,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   centroids = pd.read_csv('geocorr.csv', encoding='ISO-8859-1')

# %%
centroids
# Out:
#             county    tract       state         stab          CountyName  \
# 0      County code    Tract  State code  State abbr.         County name
# 1            01001  0201.00          01           AL          Autauga AL
# 2            01001  0202.00          01           AL          Autauga AL
# 3            01001  0203.00          01           AL          Autauga AL
# 4            01001  0204.00          01           AL          Autauga AL
# ...            ...      ...         ...          ...                 ...
# 84777        72153  7505.01          72           PR  Yauco Municipio PR
# 84778        72153  7505.02          72           PR  Yauco Municipio PR
# 84779        72153  7505.03          72           PR  Yauco Municipio PR
# 84780        72153  7506.01          72           PR  Yauco Municipio PR
# 84781        72153  7506.02          72           PR  Yauco Municipio PR
#
#                                 pop20                    IntPtLat  \
# 0      Total population (2020 Census)  Weighted centroid latitude
# 1                                1775                   32.476823
# 2                                2055                   32.471897
# 3                                3216                   32.474583
# 4                                4246                   32.468656
# ...                               ...                         ...
# 84777                            3968                   18.030796
# 84778                            1845                   18.025145
# 84779                            2155                   18.025852
# 84780                            4368                   18.018704
# 84781                            2587                   18.006421
#
#                                IntPtLon                             afact
# 0      Weighted centroid west longitude  tract-to-state allocation factor
# 1                            -86.486599                                1
# 2                            -86.472591                                1
# 3                            -86.459254                                1
# 4                            -86.442995                                1
# ...                                 ...                               ...
# 84777                        -66.868112                                 1
# 84778                        -66.860927                                 1
# 84779                         -66.87391                                 1
# 84780                         -66.84394                                 1
# 84781                        -66.860885                                 1
#
# [84782 rows x 9 columns]

# %%
centroids = centroids.iloc[1:]

# %%
centroids
# Out:
#       county    tract state stab          CountyName pop20   IntPtLat  \
# 1      01001  0201.00    01   AL          Autauga AL  1775  32.476823
# 2      01001  0202.00    01   AL          Autauga AL  2055  32.471897
# 3      01001  0203.00    01   AL          Autauga AL  3216  32.474583
# 4      01001  0204.00    01   AL          Autauga AL  4246  32.468656
# 5      01001  0205.01    01   AL          Autauga AL  4322  32.451532
# ...      ...      ...   ...  ...                 ...   ...        ...
# 84777  72153  7505.01    72   PR  Yauco Municipio PR  3968  18.030796
# 84778  72153  7505.02    72   PR  Yauco Municipio PR  1845  18.025145
# 84779  72153  7505.03    72   PR  Yauco Municipio PR  2155  18.025852
# 84780  72153  7506.01    72   PR  Yauco Municipio PR  4368  18.018704
# 84781  72153  7506.02    72   PR  Yauco Municipio PR  2587  18.006421
#
#          IntPtLon afact
# 1      -86.486599    1
# 2      -86.472591    1
# 3      -86.459254    1
# 4      -86.442995    1
# 5      -86.424422    1
# ...           ...   ...
# 84777  -66.868112     1
# 84778  -66.860927     1
# 84779   -66.87391     1
# 84780   -66.84394     1
# 84781  -66.860885     1
#
# [84781 rows x 9 columns]

# %%
def format_tract_to_6_digits(x):
    x = str(x)  # Convert to string to handle both integer and decimal cases
    if '.' in x:  # Check if there's a decimal point
        base, decimal = x.split('.')  # Split into base and decimal parts
        # Ensure the base is 4 digits and the decimal is 2 digits
        return f"{int(base):04d}{decimal[:2].ljust(2, '0')}"  # Ensure 6 digits
    else:
        # For whole number tracts (e.g., 7506), pad to 6 digits
        return f"{int(x):06d}"  # Pad to 6 digits

# Apply this function to your tract column
centroids['formatted_tract'] = centroids['tract'].apply(format_tract_to_6_digits)
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_76457/4069857016.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centroids['formatted_tract'] = centroids['tract'].apply(format_tract_to_6_digits)

# %%
centroids
# Out:
#       county    tract state stab          CountyName pop20   IntPtLat  \
# 1      01001  0201.00    01   AL          Autauga AL  1775  32.476823
# 2      01001  0202.00    01   AL          Autauga AL  2055  32.471897
# 3      01001  0203.00    01   AL          Autauga AL  3216  32.474583
# 4      01001  0204.00    01   AL          Autauga AL  4246  32.468656
# 5      01001  0205.01    01   AL          Autauga AL  4322  32.451532
# ...      ...      ...   ...  ...                 ...   ...        ...
# 84777  72153  7505.01    72   PR  Yauco Municipio PR  3968  18.030796
# 84778  72153  7505.02    72   PR  Yauco Municipio PR  1845  18.025145
# 84779  72153  7505.03    72   PR  Yauco Municipio PR  2155  18.025852
# 84780  72153  7506.01    72   PR  Yauco Municipio PR  4368  18.018704
# 84781  72153  7506.02    72   PR  Yauco Municipio PR  2587  18.006421
#
#          IntPtLon afact formatted_tract
# 1      -86.486599    1           020100
# 2      -86.472591    1           020200
# 3      -86.459254    1           020300
# 4      -86.442995    1           020400
# 5      -86.424422    1           020501
# ...           ...   ...             ...
# 84777  -66.868112     1          750501
# 84778  -66.860927     1          750502
# 84779   -66.87391     1          750503
# 84780   -66.84394     1          750601
# 84781  -66.860885     1          750602
#
# [84781 rows x 10 columns]

# %%
# Remove the first two digits from the county code and pad to 3 digits if necessary
centroids['formatted_county'] = centroids['county'].astype(str).str[2:].str.zfill(3)
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_76457/3670846890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centroids['formatted_county'] = centroids['county'].astype(str).str[2:].str.zfill(3)

# %%
centroids
# Out:
#       county    tract state stab          CountyName pop20   IntPtLat  \
# 1      01001  0201.00    01   AL          Autauga AL  1775  32.476823
# 2      01001  0202.00    01   AL          Autauga AL  2055  32.471897
# 3      01001  0203.00    01   AL          Autauga AL  3216  32.474583
# 4      01001  0204.00    01   AL          Autauga AL  4246  32.468656
# 5      01001  0205.01    01   AL          Autauga AL  4322  32.451532
# ...      ...      ...   ...  ...                 ...   ...        ...
# 84777  72153  7505.01    72   PR  Yauco Municipio PR  3968  18.030796
# 84778  72153  7505.02    72   PR  Yauco Municipio PR  1845  18.025145
# 84779  72153  7505.03    72   PR  Yauco Municipio PR  2155  18.025852
# 84780  72153  7506.01    72   PR  Yauco Municipio PR  4368  18.018704
# 84781  72153  7506.02    72   PR  Yauco Municipio PR  2587  18.006421
#
#          IntPtLon afact formatted_tract formatted_county
# 1      -86.486599    1           020100              001
# 2      -86.472591    1           020200              001
# 3      -86.459254    1           020300              001
# 4      -86.442995    1           020400              001
# 5      -86.424422    1           020501              001
# ...           ...   ...             ...              ...
# 84777  -66.868112     1          750501              153
# 84778  -66.860927     1          750502              153
# 84779   -66.87391     1          750503              153
# 84780   -66.84394     1          750601              153
# 84781  -66.860885     1          750602              153
#
# [84781 rows x 11 columns]

# %%
centroids['GEOID'] = (
    centroids['state'].astype(str).str.zfill(2) +
    centroids['formatted_county'] +
    centroids['formatted_tract']
)
# Out:
# /var/folders/mb/f5zh4qyd6sbf171lrlnmff040000gn/T/ipykernel_76457/3079041288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centroids['GEOID'] = (

# %%
centroids
# Out:
#       county    tract state stab          CountyName pop20   IntPtLat  \
# 1      01001  0201.00    01   AL          Autauga AL  1775  32.476823
# 2      01001  0202.00    01   AL          Autauga AL  2055  32.471897
# 3      01001  0203.00    01   AL          Autauga AL  3216  32.474583
# 4      01001  0204.00    01   AL          Autauga AL  4246  32.468656
# 5      01001  0205.01    01   AL          Autauga AL  4322  32.451532
# ...      ...      ...   ...  ...                 ...   ...        ...
# 84777  72153  7505.01    72   PR  Yauco Municipio PR  3968  18.030796
# 84778  72153  7505.02    72   PR  Yauco Municipio PR  1845  18.025145
# 84779  72153  7505.03    72   PR  Yauco Municipio PR  2155  18.025852
# 84780  72153  7506.01    72   PR  Yauco Municipio PR  4368  18.018704
# 84781  72153  7506.02    72   PR  Yauco Municipio PR  2587  18.006421
#
#          IntPtLon afact formatted_tract formatted_county        GEOID
# 1      -86.486599    1           020100              001  01001020100
# 2      -86.472591    1           020200              001  01001020200
# 3      -86.459254    1           020300              001  01001020300
# 4      -86.442995    1           020400              001  01001020400
# 5      -86.424422    1           020501              001  01001020501
# ...           ...   ...             ...              ...          ...
# 84777  -66.868112     1          750501              153  72153750501
# 84778  -66.860927     1          750502              153  72153750502
# 84779   -66.87391     1          750503              153  72153750503
# 84780   -66.84394     1          750601              153  72153750601
# 84781  -66.860885     1          750602              153  72153750602
#
# [84781 rows x 12 columns]

# %%
# Find rows where the GEOID is not 11 characters long
invalid_geoids = centroids[centroids['GEOID'].str.len() != 11]

# Display the problematic rows
invalid_geoids[['state', 'formatted_county', 'formatted_tract', 'GEOID']]
# Out:
# Empty DataFrame
# Columns: [state, formatted_county, formatted_tract, GEOID]
# Index: []

# %%
centroids_filter = centroids[['GEOID','IntPtLat','IntPtLon']]

# %%
merged = df.merge(centroids_filter, on='GEOID', how='left')

# %%
merged.head(100)
# Out:
#     STATEFP  COUNTYFP  TRACTCE             AFFGEOID        GEOID  \
# 0      10.0       1.0  40100.0  140000US10001040100  10001040100
# 1      10.0       1.0  40201.0  140000US10001040201  10001040201
# 2      10.0       1.0  40203.0  140000US10001040203  10001040203
# 3      10.0       1.0  40204.0  140000US10001040204  10001040204
# 4      10.0       1.0  40204.0  140000US10001040204  10001040204
# ..      ...       ...      ...                  ...          ...
# 95     10.0       3.0  12000.0  140000US10003012000  10003012000
# 96     10.0       3.0  12100.0  140000US10003012100  10003012100
# 97     10.0       3.0  12200.0  140000US10003012200  10003012200
# 98     10.0       3.0  12300.0  140000US10003012300  10003012300
# 99     10.0       3.0  12400.0  140000US10003012400  10003012400
#
#       GEOID_2020           COUNTY_x StateDesc STATEABBR  \
# 0   1.000104e+10        Kent County  Delaware        DE
# 1   1.000104e+10        Kent County  Delaware        DE
# 2   1.000104e+10        Kent County  Delaware        DE
# 3   1.000104e+10        Kent County  Delaware        DE
# 4   1.000104e+10        Kent County  Delaware        DE
# ..           ...                ...       ...       ...
# 95  1.000301e+10  New Castle County  Delaware        DE
# 96  1.000301e+10  New Castle County  Delaware        DE
# 97  1.000301e+10  New Castle County  Delaware        DE
# 98  1.000301e+10  New Castle County  Delaware        DE
# 99  1.000301e+10  New Castle County  Delaware        DE
#
#                                          LOCATION  ...  COUNTY_y    TRACT  \
# 0         Census Tract 401; Kent County; Delaware  ...       1.0  40100.0
# 1      Census Tract 402.01; Kent County; Delaware  ...       NaN      NaN
# 2      Census Tract 402.03; Kent County; Delaware  ...       NaN      NaN
# 3      Census Tract 402.04; Kent County; Delaware  ...       1.0  40204.0
# 4      Census Tract 402.04; Kent County; Delaware  ...       1.0  40204.0
# ..                                            ...  ...       ...      ...
# 95  Census Tract 120; New Castle County; Delaware  ...       3.0  12000.0
# 96  Census Tract 121; New Castle County; Delaware  ...       3.0  12100.0
# 97  Census Tract 122; New Castle County; Delaware  ...       NaN      NaN
# 98  Census Tract 123; New Castle County; Delaware  ...       NaN      NaN
# 99  Census Tract 124; New Castle County; Delaware  ...       NaN      NaN
#
#     contains_energy_source  Technology_Category  Category_Number  \
# 0                        1                Solar                1
# 1                        0                  NaN                0
# 2                        0                  NaN                0
# 3                        1                Solar                1
# 4                        1          Natural Gas                2
# ..                     ...                  ...              ...
# 95                       1            Petroleum                6
# 96                       1          Natural Gas                2
# 97                       0                  NaN                0
# 98                       0                  NaN                0
# 99                       0                  NaN                0
#
#     fossil_fuels  renewables  energy_category_numeric   IntPtLat    IntPtLon
# 0              0           1                      1.0  39.237913  -75.680806
# 1              0           0                      0.0   39.29525  -75.626415
# 2              0           0                      0.0  39.285731  -75.586928
# 3              0           1                      1.0  39.283842   -75.61762
# 4              1           0                      2.0  39.283842   -75.61762
# ..           ...         ...                      ...        ...         ...
# 95             1           0                      3.0  39.740215  -75.627634
# 96             1           0                      2.0  39.747242  -75.618115
# 97             0           0                      0.0  39.747116  -75.598514
# 98             0           0                      0.0  39.742233  -75.592391
# 99             0           0                      0.0  39.736084  -75.601553
#
# [100 rows x 197 columns]

# %%
merged[merged['Category_Number'] == 2]
# Out:
#        STATEFP  COUNTYFP  TRACTCE             AFFGEOID        GEOID  \
# 4         10.0       1.0  40204.0  140000US10001040204  10001040204
# 9         10.0       1.0  40502.0  140000US10001040502  10001040502
# 17        10.0       1.0  41400.0  140000US10001041400  10001041400
# 77        10.0       3.0  10704.0  140000US10003010704  10003010704
# 96        10.0       3.0  12100.0  140000US10003012100  10003012100
# ...        ...       ...      ...                  ...          ...
# 89269      NaN       NaN      NaN                  NaN  09011980000
# 89270      NaN       NaN      NaN                  NaN  09011980000
# 89276      NaN       NaN      NaN                  NaN  09013881200
# 89284      NaN       NaN      NaN                  NaN  09015904400
# 89285      NaN       NaN      NaN                  NaN  09015904400
#
#          GEOID_2020           COUNTY_x StateDesc STATEABBR  \
# 4      1.000104e+10        Kent County  Delaware        DE
# 9      1.000104e+10        Kent County  Delaware        DE
# 17     1.000104e+10        Kent County  Delaware        DE
# 77     1.000301e+10  New Castle County  Delaware        DE
# 96     1.000301e+10  New Castle County  Delaware        DE
# ...             ...                ...       ...       ...
# 89269           NaN                NaN       NaN       NaN
# 89270           NaN                NaN       NaN       NaN
# 89276           NaN                NaN       NaN       NaN
# 89284           NaN                NaN       NaN       NaN
# 89285           NaN                NaN       NaN       NaN
#
#                                                LOCATION  ...  COUNTY_y  \
# 4            Census Tract 402.04; Kent County; Delaware  ...       1.0
# 9            Census Tract 405.02; Kent County; Delaware  ...       1.0
# 17              Census Tract 414; Kent County; Delaware  ...       1.0
# 77     Census Tract 107.04; New Castle County; Delaware  ...       3.0
# 96        Census Tract 121; New Castle County; Delaware  ...       3.0
# ...                                                 ...  ...       ...
# 89269                                               NaN  ...      11.0
# 89270                                               NaN  ...      11.0
# 89276                                               NaN  ...      13.0
# 89284                                               NaN  ...      15.0
# 89285                                               NaN  ...      15.0
#
#           TRACT  contains_energy_source  Technology_Category  Category_Number  \
# 4       40204.0                       1          Natural Gas                2
# 9       40502.0                       1          Natural Gas                2
# 17      41400.0                       1          Natural Gas                2
# 77      10704.0                       1          Natural Gas                2
# 96      12100.0                       1          Natural Gas                2
# ...         ...                     ...                  ...              ...
# 89269  980000.0                       1          Natural Gas                2
# 89270  980000.0                       1          Natural Gas                2
# 89276  881200.0                       1          Natural Gas                2
# 89284  904400.0                       1          Natural Gas                2
# 89285  904400.0                       1          Natural Gas                2
#
#        fossil_fuels  renewables  energy_category_numeric   IntPtLat  \
# 4                 1           0                      2.0  39.283842
# 9                 1           0                      2.0  39.210368
# 17                1           0                      2.0  39.153268
# 77                1           0                      2.0  39.757675
# 96                1           0                      2.0  39.747242
# ...             ...         ...                      ...        ...
# 89269             1           0                      2.0  41.394668
# 89270             1           0                      2.0  41.394668
# 89276             1           0                      2.0  41.808076
# 89284             1           0                      2.0  41.834661
# 89285             1           0                      2.0  41.834661
#
#          IntPtLon
# 4       -75.61762
# 9      -75.530763
# 17     -75.539927
# 77     -75.510982
# 96     -75.618115
# ...           ...
# 89269  -72.083933
# 89270  -72.083933
# 89276  -72.252674
# 89284  -71.892178
# 89285  -71.892178
#
# [1602 rows x 197 columns]

# %%
total_geoids = merged[merged['Category_Number'] == 2]['GEOID'].nunique()
print(total_geoids)
# Out:
# 1352

# %%
print(list(merged.columns))
# Out:
# ['STATEFP', 'COUNTYFP', 'TRACTCE', 'AFFGEOID', 'GEOID', 'GEOID_2020', 'COUNTY_x', 'StateDesc', 'STATEABBR', 'LOCATION', 'E_TOTPOP', 'M_TOTPOP', 'E_DAYPOP', 'SPL_EJI', 'RPL_EJI', 'SPL_SER', 'RPL_SER', 'SPL_EJI_CBM', 'RPL_EJI_CBM', 'E_MINRTY', 'EPL_MINRTY', 'SPL_SVM_DOM1', 'RPL_SVM_DOM1', 'E_POV200', 'EPL_POV200', 'E_NOHSDP', 'EPL_NOHSDP', 'E_UNEMP', 'EPL_UNEMP', 'E_RENTER', 'EPL_RENTER', 'E_HOUBDN', 'EPL_HOUBDN', 'E_UNINSUR', 'EPL_UNINSUR', 'E_NOINT', 'EPL_NOINT', 'SPL_SVM_DOM2', 'RPL_SVM_DOM2', 'E_AGE65', 'EPL_AGE65', 'E_AGE17', 'EPL_AGE17', 'E_DISABL', 'EPL_DISABL', 'E_LIMENG', 'EPL_LIMENG', 'SPL_SVM_DOM3', 'RPL_SVM_DOM3', 'E_MOBILE', 'EPL_MOBILE', 'E_GROUPQ', 'EPL_GROUPQ', 'SPL_SVM_DOM4', 'RPL_SVM_DOM4', 'SPL_SVM', 'RPL_SVM', 'E_OZONE', 'EPL_OZONE', 'E_PM', 'EPL_PM', 'E_DSLPM', 'EPL_DSLPM', 'E_TOTCR', 'EPL_TOTCR', 'SPL_EBM_DOM1', 'RPL_EBM_DOM1', 'E_NPL', 'EPL_NPL', 'E_TRI', 'EPL_TRI', 'E_TSD', 'EPL_TSD', 'E_RMP', 'EPL_RMP', 'E_COAL', 'EPL_COAL', 'E_LEAD', 'EPL_LEAD', 'SPL_EBM_DOM2', 'RPL_EBM_DOM2', 'E_PARK', 'EPL_PARK', 'E_HOUAGE', 'EPL_HOUAGE', 'E_WLKIND', 'EPL_WLKIND', 'SPL_EBM_DOM3', 'RPL_EBM_DOM3', 'E_RAIL', 'EPL_RAIL', 'E_ROAD', 'EPL_ROAD', 'E_AIRPRT', 'EPL_AIRPRT', 'SPL_EBM_DOM4', 'RPL_EBM_DOM4', 'E_IMPWTR', 'EPL_IMPWTR', 'F_IMPWTR', 'SPL_EBM_DOM5', 'RPL_EBM_DOM5', 'SPL_EBM', 'RPL_EBM', 'E_ASTHMA', 'EPL_ASTHMA', 'F_ASTHMA', 'E_CANCER', 'EPL_CANCER', 'F_CANCER', 'E_CHD', 'EPL_CHD', 'F_CHD', 'E_MHLTH', 'EPL_MHLTH', 'F_MHLTH', 'E_DIABETES', 'EPL_DIABETES', 'F_DIABETES', 'F_HVM', 'RPL_HVM', 'E_NEHD', 'EPL_NEHD', 'SPL_CBM_DOM1', 'RPL_CBM_DOM1', 'E_BURN', 'EPL_BURN', 'E_SMOKE', 'EPL_SMOKE', 'SPL_CBM_DOM2', 'RPL_CBM_DOM2', 'E_CFLD', 'EPL_CFLD', 'F_CFLD', 'E_DRGT', 'EPL_DRGT', 'F_DRGT', 'E_HRCN', 'EPL_HRCN', 'F_HRCN', 'E_RFLD', 'EPL_RFLD', 'F_RFLD', 'E_SWND', 'EPL_SWND', 'F_SWND', 'E_TRND', 'EPL_TRND', 'F_TRND', 'SPL_CBM_DOM3', 'RPL_CBM_DOM3', 'SPL_CBM', 'RPL_CBM', 'AFAM', 'E_AFAM', 'HISP', 'E_HISP', 'ASIAN', 'E_ASIAN', 'AIAN', 'E_AIAN', 'NHPI', 'E_NHPI', 'TWOMORE', 'E_TWOMORE', 'OTHERRACE', 'E_OTHERRACE', 'Tribe_PCT_Tract', 'Tribe_Names', 'Tribe_Flag', 'Unnamed: 0.1', 'Unnamed: 0', 'plant_name', 'Plant Code', 'State', 'Sector Name', 'Prime Movers', 'Fuel Types', 'Primary Technology', 'withdrawal_volume_million_gallons', 'discharge_volume_million_gallons', 'consumption_volume_million_gallons', 'energy_category', 'map_link', 'longitude', 'latitude', 'STATE', 'COUNTY_y', 'TRACT', 'contains_energy_source', 'Technology_Category', 'Category_Number', 'fossil_fuels', 'renewables', 'energy_category_numeric', 'IntPtLat', 'IntPtLon']

# %%
# Filter natural gas power plants
natural_gas = merged[merged['Category_Number'] == 2][['latitude', 'longitude']]

# %%
tracts = merged[['GEOID', 'IntPtLat', 'IntPtLon', 'Category_Number']].copy()

# %%
from scipy.spatial import cKDTree
import numpy as np

# %%
# Check how many rows have missing centroid coordinates
missing_coords = tracts[tracts[['IntPtLat', 'IntPtLon']].isnull().any(axis=1)]
print(f"Number of tracts with missing centroid coordinates: {len(missing_coords)}")
# Out:
# Number of tracts with missing centroid coordinates: 1308

# %%
# Print the rows with missing centroid coordinates
missing_coords = tracts[tracts[['IntPtLat', 'IntPtLon']].isnull().any(axis=1)]
missing_coords[['GEOID', 'IntPtLat', 'IntPtLon']]
# Out:
#              GEOID IntPtLat IntPtLon
# 189    10003980100      NaN      NaN
# 190    10003980100      NaN      NaN
# 411    01015981903      NaN      NaN
# 1331   01097990000      NaN      NaN
# 2185   12009980100      NaN      NaN
# ...            ...      ...      ...
# 90168  09190257100      NaN      NaN
# 90169  09190425700      NaN      NaN
# 90170          NaN      NaN      NaN
# 90171          NaN      NaN      NaN
# 90172          NaN      NaN      NaN
#
# [1308 rows x 3 columns]

# %%
# Count the total number of rows in the DataFrame
total_rows = centroids.shape[0]
print(f"Total number of rows: {total_rows}")
# Out:
# Total number of rows: 84781

# %%
from scipy.spatial import cKDTree

# Step 1: Initialize Band column
tracts['Band'] = 0

# Step 2: Assign Band 1 to host tracts
tracts.loc[tracts['Category_Number'] == 2, 'Band'] = 1

# Step 3: Build KDTree from plant locations
plant_coords = natural_gas[['latitude', 'longitude']].to_numpy()
tree = cKDTree(plant_coords)

# Step 4: Filter non-host tracts with valid coordinates
mask_non_host = tracts['Band'] == 0
valid_coords = tracts['IntPtLat'].notna() & tracts['IntPtLon'].notna()
tract_coords = tracts.loc[mask_non_host & valid_coords, ['IntPtLat', 'IntPtLon']].to_numpy()

# Step 5: Compute distance to nearest plant
distances, _ = tree.query(tract_coords, k=1)
distances_km = distances * 111

# Step 6: Store distances temporarily
tracts.loc[mask_non_host & valid_coords, 'distance_to_plant'] = distances_km

# Step 7: Assign bands based on distance
tracts.loc[mask_non_host & (tracts['distance_to_plant'] <= 1), 'Band'] = 1  # Near-host tracts
tracts.loc[mask_non_host & (tracts['distance_to_plant'] > 1) & (tracts['distance_to_plant'] <= 5), 'Band'] = 2
tracts.loc[mask_non_host & (tracts['distance_to_plant'] > 5) & (tracts['distance_to_plant'] <= 10), 'Band'] = 3
tracts.loc[mask_non_host & (tracts['distance_to_plant'] > 10) & (tracts['distance_to_plant'] <= 20), 'Band'] = 4

# Optional: clean up
# tracts.drop(columns='distance_to_plant', inplace=True)

# %%
# Check the first few rows to ensure bands are assigned
tracts[['GEOID', 'Band']]
# Out:
#              GEOID  Band
# 0      10001040100     3
# 1      10001040201     2
# 2      10001040203     2
# 3      10001040204     1
# 4      10001040204     1
# ...            ...   ...
# 90168  09190257100     0
# 90169  09190425700     0
# 90170          NaN     0
# 90171          NaN     0
# 90172          NaN     0
#
# [90173 rows x 2 columns]

# %%
tracts['Band'].value_counts().reset_index().sort_values(by='Band')
# Out:
#    Band  count
# 0     0  43032
# 4     1   2043
# 3     2  12150
# 2     3  14817
# 1     4  18131

# %%
tracts
# Out:
#              GEOID   IntPtLat    IntPtLon  Category_Number  Band  \
# 0      10001040100  39.237913  -75.680806                1     3
# 1      10001040201   39.29525  -75.626415                0     2
# 2      10001040203  39.285731  -75.586928                0     2
# 3      10001040204  39.283842   -75.61762                1     1
# 4      10001040204  39.283842   -75.61762                2     1
# ...            ...        ...         ...              ...   ...
# 90168  09190257100        NaN         NaN                0     0
# 90169  09190425700        NaN         NaN                0     0
# 90170          NaN        NaN         NaN                4     0
# 90171          NaN        NaN         NaN                3     0
# 90172          NaN        NaN         NaN                1     0
#
#        distance_to_plant
# 0               7.800062
# 1               1.805115
# 2               4.170896
# 3               0.870727
# 4                    NaN
# ...                  ...
# 90168                NaN
# 90169                NaN
# 90170                NaN
# 90171                NaN
# 90172                NaN
#
# [90173 rows x 6 columns]

# %%
# Drop any old Band or distance columns to avoid duplication
merged = merged.drop(columns=['Band', 'distance_to_plant'], errors='ignore')

# %%
# Merge Band and distance info from tracts based on GEOID
bands = merged.merge(
    tracts[['GEOID', 'Band', 'distance_to_plant']],
    on='GEOID',
    how='left'
)

# %%
bands
# Out:
#         STATEFP  COUNTYFP  TRACTCE             AFFGEOID        GEOID  \
# 0          10.0       1.0  40100.0  140000US10001040100  10001040100
# 1          10.0       1.0  40201.0  140000US10001040201  10001040201
# 2          10.0       1.0  40203.0  140000US10001040203  10001040203
# 3          10.0       1.0  40204.0  140000US10001040204  10001040204
# 4          10.0       1.0  40204.0  140000US10001040204  10001040204
# ...         ...       ...      ...                  ...          ...
# 117034      NaN       NaN      NaN                  NaN          NaN
# 117035      NaN       NaN      NaN                  NaN          NaN
# 117036      NaN       NaN      NaN                  NaN          NaN
# 117037      NaN       NaN      NaN                  NaN          NaN
# 117038      NaN       NaN      NaN                  NaN          NaN
#
#           GEOID_2020     COUNTY_x StateDesc STATEABBR  \
# 0       1.000104e+10  Kent County  Delaware        DE
# 1       1.000104e+10  Kent County  Delaware        DE
# 2       1.000104e+10  Kent County  Delaware        DE
# 3       1.000104e+10  Kent County  Delaware        DE
# 4       1.000104e+10  Kent County  Delaware        DE
# ...              ...          ...       ...       ...
# 117034           NaN          NaN       NaN       NaN
# 117035           NaN          NaN       NaN       NaN
# 117036           NaN          NaN       NaN       NaN
# 117037           NaN          NaN       NaN       NaN
# 117038           NaN          NaN       NaN       NaN
#
#                                           LOCATION  ...  \
# 0          Census Tract 401; Kent County; Delaware  ...
# 1       Census Tract 402.01; Kent County; Delaware  ...
# 2       Census Tract 402.03; Kent County; Delaware  ...
# 3       Census Tract 402.04; Kent County; Delaware  ...
# 4       Census Tract 402.04; Kent County; Delaware  ...
# ...                                            ...  ...
# 117034                                         NaN  ...
# 117035                                         NaN  ...
# 117036                                         NaN  ...
# 117037                                         NaN  ...
# 117038                                         NaN  ...
#
#         contains_energy_source  Technology_Category  Category_Number  \
# 0                            1                Solar                1
# 1                            0                  NaN                0
# 2                            0                  NaN                0
# 3                            1                Solar                1
# 4                            1                Solar                1
# ...                        ...                  ...              ...
# 117034                       1                 Wind                3
# 117035                       1                 Wind                3
# 117036                       1                Solar                1
# 117037                       1                Solar                1
# 117038                       1                Solar                1
#
#         fossil_fuels  renewables  energy_category_numeric   IntPtLat  \
# 0                  0           1                      1.0  39.237913
# 1                  0           0                      0.0   39.29525
# 2                  0           0                      0.0  39.285731
# 3                  0           1                      1.0  39.283842
# 4                  0           1                      1.0  39.283842
# ...              ...         ...                      ...        ...
# 117034             0           1                      1.0        NaN
# 117035             0           1                      1.0        NaN
# 117036             0           1                      1.0        NaN
# 117037             0           1                      1.0        NaN
# 117038             0           1                      1.0        NaN
#
#           IntPtLon  Band  distance_to_plant
# 0       -75.680806     3           7.800062
# 1       -75.626415     2           1.805115
# 2       -75.586928     2           4.170896
# 3        -75.61762     1           0.870727
# 4        -75.61762     1                NaN
# ...            ...   ...                ...
# 117034         NaN     0                NaN
# 117035         NaN     0                NaN
# 117036         NaN     0                NaN
# 117037         NaN     0                NaN
# 117038         NaN     0                NaN
#
# [117039 rows x 199 columns]

# %%
bands.to_csv('eji_plants_with_bands.csv',index=False)

# %% [markdown]
# Band 1 is for tracts that host power plants or those whose distance from the tract's centroid to the closest power plant facility is greater than up to 1km.
# Band 2 will be for tracts that do not host power plants but whose distance from the tract's centroid to the closest power plant facility is greater than 1 km and up to 5km.
# Band 3 is for tracts that do not host power plants but whose distance from the tract's centroid to the closest power plant facility is greater than 5 km and up to 10 km.
# Band 4 is for tracts that do not host power plants but whose distance from the tract's centroid to the closest power plant facility is greater than 10 km and up to 20 km.
