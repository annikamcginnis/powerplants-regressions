# %% [markdown]
# # Natural Gas Powerplants and Environmental Justice - Nationwide and in Maryland

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# require('DescTools')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse
# Loading required package: DescTools

# %%
df = pd.read_csv('grants_merged_plants_eji.csv')
df.head()
# Out:
#    Unnamed: 0.2  STATEFP  COUNTYFP  TRACTCE             AFFGEOID       GEOID  \
# 0             0        1         1    20804  140000US01001020804  1001020804
# 1             1        1         3    10706  140000US01003010706  1003010706
# 2             2        1         3    11503  140000US01003011503  1003011503
# 3             3        1         3    11604  140000US01003011604  1003011604
# 4             4        1         5   950100  140000US01005950100  1005950100
#
#    GEOID_2020        COUNTY_x StateDesc STATEABBR  ... State_y  \
# 0  1001020804  Autauga County   Alabama        AL  ...     NaN
# 1  1003010706  Baldwin County   Alabama        AL  ...     NaN
# 2  1003011503  Baldwin County   Alabama        AL  ...     NaN
# 3  1003011604  Baldwin County   Alabama        AL  ...     NaN
# 4  1005950100  Barbour County   Alabama        AL  ...     NaN
#
#    Assistance Listing   Program  Investment Category  Website Url  \
# 0                 NaN       NaN                  NaN          NaN
# 1                 NaN       NaN                  NaN          NaN
# 2                 NaN       NaN                  NaN          NaN
# 3                 NaN       NaN                  NaN          NaN
# 4                 NaN       NaN                  NaN          NaN
#
#    Announcement Url  Data Extract Date  STATE_y  COUNTY  TRACT_y
# 0               NaN                NaN      NaN     NaN      NaN
# 1               NaN                NaN      NaN     NaN      NaN
# 2               NaN                NaN      NaN     NaN      NaN
# 3               NaN                NaN      NaN     NaN      NaN
# 4               NaN                NaN      NaN     NaN      NaN
#
# [5 rows x 222 columns]

# %%
df['natural_gas'] = (df['Category_Number'] == 2).astype(int)

# %%
pd.set_option('display.max_columns', None)

# %%
df[df['Category_Number'] == 2]
# Out:
#        Unnamed: 0.2  STATEFP  COUNTYFP  TRACTCE             AFFGEOID  \
# 11078         11078       53        39   950103  140000US53039950103
# 12774         12774       12        95    16902  140000US12095016902
# 12832         12832       55        17    10400  140000US55017010400
# 13391         13391       12        97    40810  140000US12097040810
# 13699         13699       10         3    12100  140000US10003012100
# ...             ...      ...       ...      ...                  ...
# 90524         90524       51       683   910402  140000US51683910402
# 90567         90567       55        31    30302  140000US55031030302
# 90692         90692       53        15     1501  140000US53015001501
# 90697         90697       53        25    11406  140000US53025011406
# 90770         90770       55       131   470100  140000US55131470100
#
#              GEOID   GEOID_2020           COUNTY_x   StateDesc STATEABBR  \
# 11078  53039950103  53039950103   Klickitat County  Washington        WA
# 12774  12095016902  12095016902      Orange County     Florida        FL
# 12832  55017010400  55017010400    Chippewa County   Wisconsin        WI
# 13391  12097040810  12097040810     Osceola County     Florida        FL
# 13699  10003012100  10003012100  New Castle County    Delaware        DE
# ...            ...          ...                ...         ...       ...
# 90524  51683910402  51683910402      Manassas city    Virginia        VA
# 90567  55031030302  55031030302     Douglas County   Wisconsin        WI
# 90692  53015001501  53015001501     Cowlitz County  Washington        WA
# 90697  53025011406  53025011406       Grant County  Washington        WA
#        E_TWOMORE  OTHERRACE  E_OTHERRACE  Tribe_PCT_Tract  \
# 11078        3.5        0.0          0.0         0.111471
# 12774        3.1      195.0          3.1         0.000000
# 12832        2.7        0.0          0.0         0.000000
# 13391        0.1        0.0          0.0         0.000000
# 13699        0.9        0.0          0.0         0.000000
# ...          ...        ...          ...              ...
# 90524        5.2        0.0          0.0         0.000000
# 90567        3.1        2.0          0.1         0.114974
# 90692        2.2        0.0          0.0         0.000000
# 90697        1.7        0.0          0.0         0.000000
# 90770        3.6       14.0          0.2         0.000000
#
#                                     Tribe_Names  Tribe_Flag  Unnamed: 0.1  \
# 11078  Yakama Nation Off-Reservation Trust Land         1.0        2238.0
# 12774                                      -999         NaN        4014.0
# 12832                                      -999         NaN       10774.0
# 13391                                      -999         NaN        9170.0
# 13699                                      -999         NaN         146.0
# ...                                         ...         ...           ...
# 90524                                      -999         NaN        7890.0
# 90567    Fond du Lac Off-Reservation Trust Land         1.0       11748.0
# 90692                                      -999         NaN        7145.0
# 90697                                      -999         NaN        4645.0
# 90770                                      -999         NaN       11625.0
#
#        Unnamed: 0                        plant_name  Plant Code State_x  \
# 11078         7.0   Chicago West Side Energy Center     59794.0      IL
# 12774         9.0    Fountain Valley Power Facility     55453.0      CO
# 12832         3.0          Tanner Street Generation     54586.0      MA
# 13391         7.0      Rockingham County CT Station     55116.0      NC
# 13699         7.0      AGT001 Centerville Fuel Cell     63700.0      DE
# ...           ...                               ...         ...     ...
# 90524         3.0  Odyssey Energy Altura Cogen, LLC     50815.0      TX
# 90567         8.0          Walnut Creek Energy Park     57515.0      CA
# 90692         8.0            Mooseheart Power House     50337.0      IL
# 90697         2.0                       Greenleaf 1     10350.0      CA
# 90770         5.0                           WAL5045     64947.0      TX
#
#               Sector Name Prime Movers Fuel Types  \
# 11078             IPP CHP           GT         NG
# 12774         IPP Non-CHP           GT         NG
# 12832         IPP Non-CHP       CA, CT         NG
# 13391    Electric Utility           GT         NG
# 13699         IPP Non-CHP           FC         NG
# ...                   ...          ...        ...
# 90524             IPP CHP       CA, CT         NG
# 90567         IPP Non-CHP           GT         NG
# 90692      Commercial CHP           IC         NG
# 90697         IPP Non-CHP           GT         NG
# 90770  Commercial Non-CHP           IC         NG
#
#                            Primary Technology  \
# 11078    Natural Gas Fired Combustion Turbine
# 12774    Natural Gas Fired Combustion Turbine
# 12832        Natural Gas Fired Combined Cycle
# 13391    Natural Gas Fired Combustion Turbine
# 13699                       Other Natural Gas
# ...                                       ...
# 90524        Natural Gas Fired Combined Cycle
# 90567    Natural Gas Fired Combustion Turbine
# 90692  Natural Gas Internal Combustion Engine
# 90697    Natural Gas Fired Combustion Turbine
# 90770  Natural Gas Internal Combustion Engine
#
#       withdrawal_volume_million_gallons discharge_volume_million_gallons  \
# 11078                               NaN                              NaN
# 12774                               NaN                              NaN
# 12832                               NaN                              NaN
# 13391                               NaN                              NaN
# 13699                               NaN                              NaN
# ...                                 ...                              ...
# 90524                             544.0                             71.0
# 90567                               NaN                              NaN
# 90692                               NaN                              NaN
# 90697                               NaN                              NaN
# 90770                               NaN                              NaN
#
#       consumption_volume_million_gallons energy_category  \
# 11078                                NaN     Natural Gas
# 12774                                NaN     Natural Gas
# 12832                                NaN     Natural Gas
# 13391                                NaN     Natural Gas
# 13699                                NaN     Natural Gas
# ...                                  ...             ...
# 90524                              473.0     Natural Gas
# 90567                                NaN     Natural Gas
# 90692                                NaN     Natural Gas
# 90697                                NaN     Natural Gas
# 90770                                NaN     Natural Gas
#
#                                          map_link   longitude   latitude  \
# 11078   map/?center=-87.678378,41.870751&level=14  -87.678378  41.870751
# 12774      map/?center=-104.6875,38.5569&level=14 -104.687500  38.556900
# 12832   map/?center=-71.313235,42.632124&level=14  -71.313235  42.632124
# 13391       map/?center=-79.8297,36.3297&level=14  -79.829700  36.329700
# 13699     map/?center=-75.62208,39.75787&level=14  -75.622080  39.757870
# ...                                           ...         ...        ...
# 90524      map/?center=-95.10773,29.8161&level=14  -95.107730  29.816100
# 90567  map/?center=-117.944864,34.008709&level=14 -117.944864  34.008709
# 90692       map/?center=-88.3331,41.8244&level=14  -88.333100  41.824400
# 90697  map/?center=-121.696072,39.052922&level=14 -121.696072  39.052922
# 90770   map/?center=-95.594987,30.014278&level=14  -95.594987  30.014278
#
#        STATE_x  COUNTY_y   TRACT_x  contains_energy_source  \
# 11078     53.0      39.0  950103.0                       1
# 12774     12.0      95.0   16902.0                       1
# 12832     55.0      17.0   10400.0                       1
# 13391     12.0      97.0   40810.0                       1
# 13699     10.0       3.0   12100.0                       1
# ...        ...       ...       ...                     ...
# 90524     51.0     683.0  910402.0                       1
# 90567     55.0      31.0   30302.0                       1
# 90692     53.0      15.0    1501.0                       1
# 90697     53.0      25.0   11406.0                       1
# 90770     55.0     131.0  470100.0                       1
#
#       Technology_Category  Category_Number  fossil_fuels  renewables  \
# 11078         Natural Gas                2             1           0
# 12774         Natural Gas                2             1           0
# 12832         Natural Gas                2             1           0
# 13391         Natural Gas                2             1           0
# 13699         Natural Gas                2             1           0
# ...                   ...              ...           ...         ...
# 90524         Natural Gas                2             1           0
# 90567         Natural Gas                2             1           0
# 90692         Natural Gas                2             1           0
# 90697         Natural Gas                2             1           0
# 90770         Natural Gas                2             1           0
#
#        energy_category_numeric Announcement Date Award Date Project Title  \
# 11078                      2.0               NaN        NaN           NaN
# 12774                      2.0               NaN        NaN           NaN
# 12832                      2.0               NaN        NaN           NaN
# 13391                      2.0               NaN        NaN           NaN
# 13699                      2.0               NaN        NaN           NaN
# ...                        ...               ...        ...           ...
# 90524                      2.0               NaN        NaN           NaN
# 90567                      2.0               NaN        NaN           NaN
# 90692                      2.0               NaN        NaN           NaN
# 90697                      2.0               NaN        NaN           NaN
# 90770                      2.0               NaN        NaN           NaN
#
#       Project Description Recipient Funding Source Type of Award  \
# 11078                 NaN       NaN            NaN           NaN
# 12774                 NaN       NaN            NaN           NaN
# 12832                 NaN       NaN            NaN           NaN
# 13391                 NaN       NaN            NaN           NaN
# 13699                 NaN       NaN            NaN           NaN
# ...                   ...       ...            ...           ...
# 90524                 NaN       NaN            NaN           NaN
# 90567                 NaN       NaN            NaN           NaN
# 90692                 NaN       NaN            NaN           NaN
# 90697                 NaN       NaN            NaN           NaN
# 90770                 NaN       NaN            NaN           NaN
#
#       Funding Status Federal Award Identification Number Award Amount  \
# 11078            NaN                                 NaN          NaN
# 12774            NaN                                 NaN          NaN
# 12832            NaN                                 NaN          NaN
# 13391            NaN                                 NaN          NaN
# 13699            NaN                                 NaN          NaN
# ...              ...                                 ...          ...
# 90524            NaN                                 NaN          NaN
# 90567            NaN                                 NaN          NaN
# 90692            NaN                                 NaN          NaN
# 90697            NaN                                 NaN          NaN
# 90770            NaN                                 NaN          NaN
#
#       Location  Latitude  Longitude  Zip Code City County State_y  \
# 11078      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 12774      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 12832      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 13391      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 13699      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# ...        ...       ...        ...       ...  ...    ...     ...
# 90524      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 90567      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 90692      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 90697      NaN       NaN        NaN       NaN  NaN    NaN     NaN
# 90770      NaN       NaN        NaN       NaN  NaN    NaN     NaN
#
#       Assistance Listing  Program Investment Category Website Url  \
# 11078                NaN      NaN                 NaN         NaN
# 12774                NaN      NaN                 NaN         NaN
# 12832                NaN      NaN                 NaN         NaN
# 13391                NaN      NaN                 NaN         NaN
# 13699                NaN      NaN                 NaN         NaN
# ...                  ...      ...                 ...         ...
# 90524                NaN      NaN                 NaN         NaN
# 90567                NaN      NaN                 NaN         NaN
# 90692                NaN      NaN                 NaN         NaN
# 90697                NaN      NaN                 NaN         NaN
# 90770                NaN      NaN                 NaN         NaN
#
#       Announcement Url Data Extract Date  STATE_y  COUNTY  TRACT_y  \
# 11078              NaN               NaN      NaN     NaN      NaN
# 12774              NaN               NaN      NaN     NaN      NaN
# 12832              NaN               NaN      NaN     NaN      NaN
# 13391              NaN               NaN      NaN     NaN      NaN
# 13699              NaN               NaN      NaN     NaN      NaN
# ...                ...               ...      ...     ...      ...
# 90524              NaN               NaN      NaN     NaN      NaN
# 90567              NaN               NaN      NaN     NaN      NaN
# 90692              NaN               NaN      NaN     NaN      NaN
# 90697              NaN               NaN      NaN     NaN      NaN
# 90770              NaN               NaN      NaN     NaN      NaN
#
#        natural_gas
# 11078            1
# 12774            1
# 12832            1
# 13391            1
# 13699            1
# ...            ...
# 90524            1
# 90567            1
# 90692            1
# 90697            1
# 90770            1
#
# [1336 rows x 223 columns]

# %%
df['natural_gas'].value_counts()
# Out:
# natural_gas
# 0    89570
# 1     1336
# Name: count, dtype: int64

# %%
# %%R -i df
# logistic <- glm(natural_gas ~ E_POV200, data=df, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200, family = "binomial", data = df)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -4.067319   0.055031 -73.910  < 2e-16 ***
# E_POV200    -0.004230   0.001624  -2.605  0.00919 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 13669  on 88382  degrees of freedom
# Residual deviance: 13662  on 88381  degrees of freedom
#   (2523 observations deleted due to missingness)
# AIC: 13666
#
# Number of Fisher Scoring iterations: 7

# %%
# %%R
#
# require('DescTools')
#
# PseudoR2(logistic, which='McFadden')
# Out:
#     McFadden
# 0.0005052876

# %%
# %%R -i df
# logistic <- glm(natural_gas ~ E_POV200 + E_AFAM, data=df, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200 + E_AFAM, family = "binomial",
#     data = df)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -4.067241   0.055604 -73.147  < 2e-16 ***
# E_POV200     0.001041   0.001728   0.602    0.547
# E_AFAM      -0.015323   0.002016  -7.601 2.93e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 13669  on 88382  degrees of freedom
# Residual deviance: 13591  on 88380  degrees of freedom
#   (2523 observations deleted due to missingness)
# AIC: 13597
#
# Number of Fisher Scoring iterations: 7

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
#    McFadden
# 0.005682703

# %%
# %%R -i df
# logistic <- glm(natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR + E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + E_ROAD + E_RAIL + E_AIRPRT + E_IMPWTR + E_SMOKE + E_NOINT + E_HOUBDN + E_RENTER + E_DAYPOP, data=df, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_AIAN +
#     E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR +
#     E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + E_ROAD + E_RAIL +
#     E_AIRPRT + E_IMPWTR + E_SMOKE + E_NOINT + E_HOUBDN + E_RENTER +
#     E_DAYPOP, family = "binomial", data = df)
#
# Coefficients:
#                Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -4.223e+00  2.377e-01 -17.767  < 2e-16 ***
# E_POV200     -1.477e-02  3.403e-03  -4.340 1.43e-05 ***
# E_AFAM       -9.339e-04  2.126e-03  -0.439 0.660494
# E_HISP        1.549e-03  2.520e-03   0.615 0.538785
# E_AIAN        4.171e-03  3.553e-03   1.174 0.240412
# E_LIMENG     -3.760e-02  1.134e-02  -3.316 0.000913 ***
# SPL_SVM_DOM4  5.282e-01  6.781e-02   7.789 6.76e-15 ***
# E_UNEMP      -4.799e-03  7.933e-03  -0.605 0.545210
# E_NOHSDP      1.758e-02  5.585e-03   3.148 0.001646 **
# E_UNINSUR    -2.318e-03  5.261e-03  -0.441 0.659523
# E_TOTPOP     -3.850e-05  1.931e-05  -1.994 0.046189 *
# E_PARK       -1.894e-03  9.608e-04  -1.971 0.048689 *
# E_AGE17       5.308e-03  5.683e-03   0.934 0.350340
# E_AGE65      -1.573e-03  4.451e-03  -0.353 0.723732
# E_ROAD       -1.193e-02  1.065e-03 -11.204  < 2e-16 ***
# E_RAIL        4.626e-03  1.020e-03   4.534 5.79e-06 ***
# E_AIRPRT     -3.205e-03  2.436e-03  -1.316 0.188222
# E_IMPWTR     -3.555e-01  9.276e-02  -3.832 0.000127 ***
# E_SMOKE       3.840e-02  4.114e-03   9.334  < 2e-16 ***
# E_NOINT       1.885e-02  3.957e-03   4.765 1.89e-06 ***
# E_HOUBDN      4.808e-03  4.331e-03   1.110 0.266978
# E_RENTER     -1.093e-02  2.523e-03  -4.331 1.49e-05 ***
# E_DAYPOP      4.303e-05  4.539e-06   9.479  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 13649  on 88305  degrees of freedom
# Residual deviance: 12593  on 88283  degrees of freedom
#   (2600 observations deleted due to missingness)
# AIC: 12639
#
# Number of Fisher Scoring iterations: 8

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
#   McFadden
# 0.07742186

# %%
# %%R -i df
# model <- lm(E_TOTCR ~ natural_gas, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_TOTCR ~ natural_gas, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -18.28  -5.28  -5.28   4.72 374.72
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 25.28244    0.02837  891.12   <2e-16 ***
# natural_gas -3.86868    0.23275  -16.62   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.399 on 88966 degrees of freedom
#   (1938 observations deleted due to missingness)
# Multiple R-squared:  0.003096,	Adjusted R-squared:  0.003085
# F-statistic: 276.3 on 1 and 88966 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_TOTCR ~ fossil_fuels, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_TOTCR ~ fossil_fuels, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -18.32  -5.32  -5.32   4.68 374.68
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  25.31501    0.02846  889.48   <2e-16 ***
# fossil_fuels -3.95061    0.18851  -20.96   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.392 on 88966 degrees of freedom
#   (1938 observations deleted due to missingness)
# Multiple R-squared:  0.004913,	Adjusted R-squared:  0.004901
# F-statistic: 439.2 on 1 and 88966 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_TOTCR ~ natural_gas + E_POV200 + E_AFAM, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_TOTCR ~ natural_gas + E_POV200 + E_AFAM, data = df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -18.50  -4.26  -3.56   5.47 375.85
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 24.247627   0.054611  444.01   <2e-16 ***
# natural_gas -3.433625   0.224792  -15.28   <2e-16 ***
# E_POV200    -0.015077   0.001679   -8.98   <2e-16 ***
# E_AFAM       0.116588   0.001444   80.73   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.085 on 88372 degrees of freedom
#   (2530 observations deleted due to missingness)
# Multiple R-squared:  0.07735,	Adjusted R-squared:  0.07732
# F-statistic:  2470 on 3 and 88372 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_CANCER ~ natural_gas, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_CANCER ~ natural_gas, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2623 -1.9944  0.1056  1.7056 19.5056
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 7.994402   0.009061  882.30   <2e-16 ***
# natural_gas 0.967898   0.074389   13.01   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.675 on 88498 degrees of freedom
#   (2406 observations deleted due to missingness)
# Multiple R-squared:  0.001909,	Adjusted R-squared:  0.001898
# F-statistic: 169.3 on 1 and 88498 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_CANCER ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ + E_TOTPOP + E_AGE65 + E_AGE17, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_CANCER ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ +
#     E_TOTPOP + E_AGE65 + E_AGE17, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -17.6986  -0.6085   0.0568   0.6690  11.7206
#
# Coefficients:
#               Estimate Std. Error  t value Pr(>|t|)
# (Intercept)  4.310e+00  2.304e-02  187.024  < 2e-16 ***
# natural_gas  1.599e-01  3.035e-02    5.268 1.38e-07 ***
# E_POV200    -1.023e-02  3.161e-04  -32.361  < 2e-16 ***
# E_AFAM      -3.765e-02  2.112e-04 -178.287  < 2e-16 ***
# E_HISP      -3.448e-02  2.523e-04 -136.689  < 2e-16 ***
# E_UNEMP      2.173e-03  9.267e-04    2.345 0.019039 *
# E_PM        -7.303e-02  5.076e-03  -14.388  < 2e-16 ***
# E_OZONE     -6.885e-03  1.816e-03   -3.793 0.000149 ***
# E_NOHSDP    -1.459e-02  6.171e-04  -23.652  < 2e-16 ***
# E_UNINSUR    1.970e-02  6.536e-04   30.141  < 2e-16 ***
# E_GROUPQ    -1.246e-02  4.978e-04  -25.031  < 2e-16 ***
# E_TOTPOP    -1.646e-05  2.331e-06   -7.059 1.69e-12 ***
# E_AGE65      2.208e-01  5.014e-04  440.377  < 2e-16 ***
# E_AGE17      6.237e-02  6.479e-04   96.267  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.088 on 88269 degrees of freedom
#   (2623 observations deleted due to missingness)
# Multiple R-squared:  0.8334,	Adjusted R-squared:  0.8334
# F-statistic: 3.397e+04 on 13 and 88269 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_ASTHMA ~ natural_gas, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_ASTHMA ~ natural_gas, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.6429 -0.9429 -0.0429  0.8571 10.0571
#
# Coefficients:
#              Estimate Std. Error  t value Pr(>|t|)
# (Intercept) 10.642864   0.004865 2187.850  < 2e-16 ***
# natural_gas  0.150281   0.039937    3.763 0.000168 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.436 on 88498 degrees of freedom
#   (2406 observations deleted due to missingness)
# Multiple R-squared:  0.00016,	Adjusted R-squared:  0.0001487
# F-statistic: 14.16 on 1 and 88498 DF,  p-value: 0.0001681

# %%
# %%R -i df
# model <- lm(E_ASTHMA ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ + E_TOTPOP + E_AGE65 + E_AGE17, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_ASTHMA ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ +
#     E_TOTPOP + E_AGE65 + E_AGE17, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3172 -0.6162 -0.0325  0.5985  6.2336
#
# Coefficients:
#               Estimate Std. Error  t value Pr(>|t|)
# (Intercept)  9.252e+00  2.107e-02  439.178  < 2e-16 ***
# natural_gas  1.546e-01  2.775e-02    5.573 2.51e-08 ***
# E_POV200     4.854e-02  2.890e-04  167.952  < 2e-16 ***
# E_AFAM       5.337e-03  1.931e-04   27.644  < 2e-16 ***
# E_HISP      -2.566e-02  2.307e-04 -111.240  < 2e-16 ***
# E_UNEMP      2.134e-02  8.472e-04   25.187  < 2e-16 ***
# E_PM         6.372e-02  4.640e-03   13.731  < 2e-16 ***
# E_OZONE      4.869e-03  1.660e-03    2.933  0.00336 **
# E_NOHSDP     2.518e-02  5.642e-04   44.625  < 2e-16 ***
# E_UNINSUR   -2.321e-02  5.975e-04  -38.836  < 2e-16 ***
# E_GROUPQ    -4.688e-03  4.551e-04  -10.301  < 2e-16 ***
# E_TOTPOP    -1.796e-05  2.132e-06   -8.427  < 2e-16 ***
# E_AGE65     -1.144e-02  4.584e-04  -24.957  < 2e-16 ***
# E_AGE17      1.597e-02  5.923e-04   26.958  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9945 on 88269 degrees of freedom
#   (2623 observations deleted due to missingness)
# Multiple R-squared:  0.5196,	Adjusted R-squared:  0.5195
# F-statistic:  7344 on 13 and 88269 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_CHD ~ natural_gas, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_CHD ~ natural_gas, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.1864 -1.4913 -0.1913  1.4087 30.0087
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 7.091280   0.007427  954.76   <2e-16 ***
# natural_gas 0.795087   0.060977   13.04   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.193 on 88498 degrees of freedom
#   (2406 observations deleted due to missingness)
# Multiple R-squared:  0.001917,	Adjusted R-squared:  0.001906
# F-statistic:   170 on 1 and 88498 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_CHD ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ + E_TOTPOP + E_AGE65 + E_AGE17, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_CHD ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_UNEMP + E_PM + E_OZONE + E_NOHSDP + E_UNINSUR + E_GROUPQ +
#     E_TOTPOP + E_AGE65 + E_AGE17, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.7294  -0.6943   0.0034   0.7036  21.0489
#
# Coefficients:
#               Estimate Std. Error  t value Pr(>|t|)
# (Intercept)  1.111e+00  2.421e-02   45.902   <2e-16 ***
# natural_gas  2.825e-01  3.189e-02    8.858   <2e-16 ***
# E_POV200     5.148e-02  3.322e-04  154.970   <2e-16 ***
# E_AFAM      -1.431e-02  2.219e-04  -64.496   <2e-16 ***
# E_HISP      -2.731e-02  2.651e-04 -103.012   <2e-16 ***
# E_UNEMP      1.508e-02  9.738e-04   15.485   <2e-16 ***
# E_PM        -1.933e-01  5.334e-03  -36.235   <2e-16 ***
# E_OZONE     -2.177e-02  1.908e-03  -11.413   <2e-16 ***
# E_NOHSDP     4.755e-02  6.484e-04   73.323   <2e-16 ***
# E_UNINSUR    2.708e-02  6.868e-04   39.428   <2e-16 ***
# E_GROUPQ    -1.121e-02  5.231e-04  -21.424   <2e-16 ***
# E_TOTPOP    -4.997e-05  2.450e-06  -20.396   <2e-16 ***
# E_AGE65      1.824e-01  5.269e-04  346.216   <2e-16 ***
# E_AGE17      6.183e-02  6.808e-04   90.823   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.143 on 88269 degrees of freedom
#   (2623 observations deleted due to missingness)
# Multiple R-squared:  0.7266,	Adjusted R-squared:  0.7266
# F-statistic: 1.805e+04 on 13 and 88269 DF,  p-value: < 2.2e-16

# %%
# %%R -i df
# model <- lm(E_PM ~ natural_gas, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_PM ~ natural_gas, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.3027 -0.3027 -0.3027 -0.1326  9.6373
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.302733   0.002611 115.952  < 2e-16 ***
# natural_gas -0.170159   0.021437  -7.938 2.08e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7736 on 89122 degrees of freedom
#   (1782 observations deleted due to missingness)
# Multiple R-squared:  0.0007065,	Adjusted R-squared:  0.0006953
# F-statistic: 63.01 on 1 and 89122 DF,  p-value: 2.085e-15

# %%
# %%R -i df
# model <- lm(E_PM ~ natural_gas + E_POV200 + E_AFAM, data=df)
# summary(model)
# Out:
# Call:
# lm(formula = E_PM ~ natural_gas + E_POV200 + E_AFAM, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.4871 -0.3446 -0.2630 -0.0488  9.5514
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.3282598  0.0051812  63.356   <2e-16 ***
# natural_gas -0.1944406  0.0213308  -9.116   <2e-16 ***
# E_POV200     0.0015880  0.0001593   9.970   <2e-16 ***
# E_AFAM      -0.0057258  0.0001370 -41.790   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7672 on 88379 degrees of freedom
#   (2523 observations deleted due to missingness)
# Multiple R-squared:  0.02057,	Adjusted R-squared:  0.02053
# F-statistic: 618.6 on 3 and 88379 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Now focusing on Maryland alone

# %%
# %%R
#
# # Import data with R
# df_md <- read_csv('md.csv', show_col_types = FALSE)
# df_md
# Out:
# New names:
# • `` -> `...1`
# # A tibble: 1,582 × 223
#     ...1 `Unnamed: 0.2` STATEFP COUNTYFP TRACTCE AFFGEOID       GEOID GEOID_2020
#    <dbl>          <dbl>   <dbl>    <dbl>   <dbl> <chr>          <dbl>      <dbl>
#  1 24209          24209      24        3  702602 140000US240… 2.40e10    2.40e10
#  2 24210          24210      24        3  706700 140000US240… 2.40e10    2.40e10
#  3 24211          24211      24        3  730205 140000US240… 2.40e10    2.40e10
#  4 24212          24212      24        3  730509 140000US240… 2.40e10    2.40e10
#  5 24852          24852      24        3  731205 140000US240… 2.40e10    2.40e10
#  6 24853          24853      24        3  731209 140000US240… 2.40e10    2.40e10
#  7 24854          24854      24        3  740703 140000US240… 2.40e10    2.40e10
#  8 27478          27478      24       21  750801 140000US240… 2.40e10    2.40e10
#  9 27479          27479      24       21  751002 140000US240… 2.40e10    2.40e10
# 10 27480          27480      24       21  752201 140000US240… 2.40e10    2.40e10
# # ℹ 1,572 more rows
# # ℹ 215 more variables: COUNTY_x <chr>, StateDesc <chr>, STATEABBR <chr>,
# #   LOCATION <chr>, E_TOTPOP <dbl>, M_TOTPOP <dbl>, E_DAYPOP <dbl>,
# #   SPL_EJI <dbl>, RPL_EJI <dbl>, SPL_SER <dbl>, RPL_SER <dbl>,
# #   SPL_EJI_CBM <dbl>, RPL_EJI_CBM <dbl>, E_MINRTY <dbl>, EPL_MINRTY <dbl>,
# #   SPL_SVM_DOM1 <dbl>, RPL_SVM_DOM1 <dbl>, E_POV200 <dbl>, EPL_POV200 <dbl>,
# #   E_NOHSDP <dbl>, EPL_NOHSDP <dbl>, E_UNEMP <dbl>, EPL_UNEMP <dbl>, …
# # ℹ Use `print(n = ...)` to see more rows, and `colnames()` to see all variable names

# %%
# %%R
#
# df_md %>%
#   group_by(Category_Number) %>%
#   summarise(median_E_POV200 = median(E_POV200, na.rm = TRUE)) %>%
#   arrange(desc(median_E_POV200))
# Out:
# # A tibble: 10 × 2
#    Category_Number median_E_POV200
#              <dbl>           <dbl>
#  1               8           28.1
#  2               3           25.9
#  3               4           25.5
#  4               7           24.7
#  5               2           21.6
#  6               5           20.9
#  7               6           20.7
#  8               1           20.3
#  9               0           19.3
# 10               9            6.00

# %% [markdown]
# ### Tracts with natural gas power plants (#2) are poorer than tracts without any type of power plant. Tracts with coal are the most poor.

# %%
# %%R
#
# df_md %>%
#   group_by(Category_Number) %>%
#   summarise(median_ASTHMA = median(E_ASTHMA, na.rm = TRUE)) %>%
#   arrange(desc(median_ASTHMA))
# Out:
# # A tibble: 10 × 2
#    Category_Number median_ASTHMA
#              <dbl>         <dbl>
#  1               5          11.4
#  2               2          11.3
#  3               4          11.3
#  4               3          11.1
#  5               1          11
#  6               6          11
#  7               8          11
#  8               0          10.9
#  9               7          10.1
# 10               9           8.2

# %% [markdown]
# ### Tracts with natural gas power plants have higher rates of asthma than most other tracts.

# %%
md = pd.read_csv('md.csv')

# %%
md['natural_gas'] = (md['Category_Number'] == 2).astype(int)

# %%
md['natural_gas'].value_counts()
# Out:
# natural_gas
# 0    1558
# 1      24
# Name: count, dtype: int64

# %%
# %%R -i md
# logistic <- glm(natural_gas ~ E_POV200, data=md, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200, family = "binomial", data = md)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -4.236717   0.365301 -11.598   <2e-16 ***
# E_POV200     0.003448   0.012920   0.267     0.79
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 247.94  on 1557  degrees of freedom
# Residual deviance: 247.87  on 1556  degrees of freedom
#   (24 observations deleted due to missingness)
# AIC: 251.87
#
# Number of Fisher Scoring iterations: 7

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
#     McFadden
# 0.0002816126

# %% [markdown]
# ### SPL_SVM_DOM4 - Domain consisting of mobile homes and housing with group quarters

# %%
# %%R -i md
# logistic <- glm(natural_gas ~ SPL_SVM_DOM4, data=md, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ SPL_SVM_DOM4, family = "binomial",
#     data = md)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -6.4480     0.6118 -10.539  < 2e-16 ***
# SPL_SVM_DOM4   2.5912     0.5164   5.017 5.24e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 247.94  on 1557  degrees of freedom
# Residual deviance: 218.48  on 1556  degrees of freedom
#   (24 observations deleted due to missingness)
# AIC: 222.48
#
# Number of Fisher Scoring iterations: 8

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
#  McFadden
# 0.1188267

# %%
# %%R -i md
# logistic <- glm(natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_LIMENG + SPL_SVM_DOM4, data=md, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_LIMENG +
#     SPL_SVM_DOM4, family = "binomial", data = md)
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -6.221499   0.746574  -8.333  < 2e-16 ***
# E_POV200     -0.004239   0.016569  -0.256    0.798
# E_AFAM        0.000907   0.009317   0.097    0.922
# E_HISP        0.005815   0.041526   0.140    0.889
# E_LIMENG     -0.075834   0.133446  -0.568    0.570
# SPL_SVM_DOM4  2.543695   0.563781   4.512 6.43e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 247.94  on 1557  degrees of freedom
# Residual deviance: 217.62  on 1552  degrees of freedom
#   (24 observations deleted due to missingness)
# AIC: 229.62
#
# Number of Fisher Scoring iterations: 8

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
#  McFadden
# 0.1222777

# %%
# %%R -i md
# logistic <- glm(natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR + E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL + E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN + E_RENTER + E_DAYPOP, data=md, family="binomial")
# summary(logistic)
# Out:
# Call:
# glm(formula = natural_gas ~ E_POV200 + E_AFAM + E_HISP + E_AIAN +
#     E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR +
#     E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL +
#     E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN +
#     E_RENTER + E_DAYPOP, family = "binomial", data = md)
#
# Coefficients:
#                Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -7.197e+00  3.636e+00  -1.979 0.047771 *
# E_POV200      1.823e-02  3.431e-02   0.531 0.595205
# E_AFAM        1.423e-02  1.229e-02   1.158 0.246828
# E_HISP       -4.447e-03  4.894e-02  -0.091 0.927604
# E_AIAN       -1.559e+00  1.570e+00  -0.993 0.320759
# E_LIMENG     -6.051e-02  1.466e-01  -0.413 0.679808
# SPL_SVM_DOM4  2.250e+00  6.437e-01   3.495 0.000474 ***
# E_UNEMP      -1.960e-02  7.605e-02  -0.258 0.796603
# E_NOHSDP      1.679e-02  5.518e-02   0.304 0.760943
# E_UNINSUR     7.626e-03  6.958e-02   0.110 0.912731
# E_TOTPOP     -1.434e-04  1.596e-04  -0.898 0.369141
# E_PARK       -7.260e-03  1.354e-02  -0.536 0.591866
# E_AGE17       3.388e-02  4.323e-02   0.784 0.433275
# E_AGE65      -3.059e-02  4.686e-02  -0.653 0.513929
# EPL_ROAD     -1.231e+00  1.414e+00  -0.871 0.383946
# E_RAIL        4.690e-03  7.105e-03   0.660 0.509218
# E_AIRPRT     -3.725e-02  2.938e-02  -1.268 0.204779
# EPL_IMPWTR   -1.087e+00  1.309e+00  -0.830 0.406570
# EPL_SMOKE     1.434e+01  8.589e+00   1.670 0.094984 .
# E_NOINT      -5.267e-02  4.553e-02  -1.157 0.247364
# E_HOUBDN     -5.867e-02  3.668e-02  -1.599 0.109745
# E_RENTER      3.008e-03  1.526e-02   0.197 0.843740
# E_DAYPOP      7.140e-05  4.307e-05   1.658 0.097318 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 247.94  on 1557  degrees of freedom
# Residual deviance: 198.42  on 1535  degrees of freedom
#   (24 observations deleted due to missingness)
# AIC: 244.42
#
# Number of Fisher Scoring iterations: 9

# %%
# %%R
#
# PseudoR2(logistic, which='McFadden')
# Out:
# McFadden
#  0.19971

# %%
# %%R -i md
# model <- lm(E_CANCER ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR + E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL + E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN + E_RENTER + E_DAYPOP, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_CANCER ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR +
#     E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL +
#     E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN +
#     E_RENTER + E_DAYPOP, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.6302 -0.4680  0.0034  0.5090  3.0596
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.532e+00  4.746e-01   7.441 1.65e-13 ***
# natural_gas  -6.437e-02  1.740e-01  -0.370 0.711503
# E_POV200     -5.320e-03  3.245e-03  -1.639 0.101362
# E_AFAM       -3.712e-02  1.013e-03 -36.626  < 2e-16 ***
# E_HISP       -3.922e-02  3.459e-03 -11.337  < 2e-16 ***
# E_AIAN       -1.600e-01  4.678e-02  -3.421 0.000641 ***
# E_LIMENG     -2.378e-02  8.172e-03  -2.910 0.003667 **
# SPL_SVM_DOM4  2.246e-01  5.530e-02   4.063 5.10e-05 ***
# E_UNEMP      -2.899e-03  6.694e-03  -0.433 0.665001
# E_NOHSDP     -1.224e-02  5.244e-03  -2.334 0.019731 *
# E_UNINSUR     2.079e-02  6.645e-03   3.129 0.001788 **
# E_TOTPOP     -1.129e-05  1.460e-05  -0.773 0.439479
# E_PARK       -2.897e-04  2.403e-03  -0.121 0.904046
# E_AGE17       6.846e-02  4.170e-03  16.418  < 2e-16 ***
# E_AGE65       1.941e-01  3.469e-03  55.960  < 2e-16 ***
# EPL_ROAD     -7.821e-01  1.422e-01  -5.501 4.42e-08 ***
# E_RAIL       -5.728e-04  6.031e-04  -0.950 0.342412
# E_AIRPRT     -4.017e-03  1.387e-03  -2.896 0.003830 **
# EPL_IMPWTR   -6.553e-03  1.664e-01  -0.039 0.968581
# EPL_SMOKE     5.363e+00  1.067e+00   5.028 5.53e-07 ***
# E_NOINT       1.014e-02  3.837e-03   2.643 0.008296 **
# E_HOUBDN     -1.513e-03  3.483e-03  -0.434 0.664137
# E_RENTER     -8.347e-03  1.474e-03  -5.662 1.78e-08 ***
# E_DAYPOP     -9.970e-06  5.332e-06  -1.870 0.061706 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8312 on 1533 degrees of freedom
#   (25 observations deleted due to missingness)
# Multiple R-squared:  0.8931,	Adjusted R-squared:  0.8915
# F-statistic:   557 on 23 and 1533 DF,  p-value: < 2.2e-16

# %%
# %%R -i md
# model <- lm(E_CANCER ~ E_AGE65 + E_AGE17, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_CANCER ~ E_AGE65 + E_AGE17, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8405 -1.1689  0.0584  1.2588  3.9605
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.640671   0.191650   8.561   <2e-16 ***
# E_AGE65     0.262059   0.005274  49.686   <2e-16 ***
# E_AGE17     0.068103   0.006557  10.386   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.6 on 1571 degrees of freedom
#   (8 observations deleted due to missingness)
# Multiple R-squared:  0.6145,	Adjusted R-squared:  0.614
# F-statistic:  1252 on 2 and 1571 DF,  p-value: < 2.2e-16

# %%
# %%R -i md
# model <- lm(E_ASTHMA ~ natural_gas, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_ASTHMA ~ natural_gas, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.5532 -0.9532 -0.1532  0.7372  7.1468
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 11.05316    0.03536 312.598   <2e-16 ***
# natural_gas  0.13851    0.28635   0.484    0.629
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.392 on 1572 degrees of freedom
#   (8 observations deleted due to missingness)
# Multiple R-squared:  0.0001488,	Adjusted R-squared:  -0.0004872
# F-statistic: 0.234 on 1 and 1572 DF,  p-value: 0.6287

# %%
# %%R -i md
# model <- lm(E_ASTHMA ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR + E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL + E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN + E_RENTER + E_DAYPOP, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_ASTHMA ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR +
#     E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL +
#     E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN +
#     E_RENTER + E_DAYPOP, data = md)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.74363 -0.38260 -0.00562  0.39258  1.85235
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   8.586e+00  3.355e-01  25.593  < 2e-16 ***
# natural_gas  -9.632e-02  1.230e-01  -0.783 0.433748
# E_POV200      4.534e-02  2.294e-03  19.766  < 2e-16 ***
# E_AFAM        1.415e-02  7.164e-04  19.753  < 2e-16 ***
# E_HISP       -2.612e-02  2.445e-03 -10.681  < 2e-16 ***
# E_AIAN       -3.965e-02  3.307e-02  -1.199 0.230707
# E_LIMENG     -6.098e-02  5.776e-03 -10.556  < 2e-16 ***
# SPL_SVM_DOM4  4.843e-02  3.909e-02   1.239 0.215530
# E_UNEMP       7.027e-03  4.731e-03   1.485 0.137685
# E_NOHSDP      4.568e-02  3.707e-03  12.323  < 2e-16 ***
# E_UNINSUR     1.963e-02  4.697e-03   4.179 3.09e-05 ***
# E_TOTPOP      2.244e-05  1.032e-05   2.175 0.029787 *
# E_PARK        3.462e-03  1.698e-03   2.038 0.041698 *
# E_AGE17       5.098e-03  2.948e-03   1.729 0.083924 .
# E_AGE65      -1.792e-02  2.452e-03  -7.309 4.32e-13 ***
# EPL_ROAD     -4.429e-01  1.005e-01  -4.407 1.12e-05 ***
# E_RAIL        7.715e-04  4.263e-04   1.810 0.070548 .
# E_AIRPRT     -7.957e-04  9.803e-04  -0.812 0.417123
# EPL_IMPWTR   -3.591e-01  1.176e-01  -3.054 0.002297 **
# EPL_SMOKE     3.625e+00  7.539e-01   4.808 1.68e-06 ***
# E_NOINT       9.771e-03  2.712e-03   3.603 0.000325 ***
# E_HOUBDN      8.391e-03  2.462e-03   3.408 0.000671 ***
# E_RENTER     -4.980e-03  1.042e-03  -4.779 1.93e-06 ***
# E_DAYPOP     -1.784e-05  3.769e-06  -4.734 2.41e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5875 on 1533 degrees of freedom
#   (25 observations deleted due to missingness)
# Multiple R-squared:  0.8259,	Adjusted R-squared:  0.8233
# F-statistic: 316.2 on 23 and 1533 DF,  p-value: < 2.2e-16

# %%
# %%R -i md
# model <- lm(E_CHD ~ natural_gas, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_CHD ~ natural_gas, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.1884 -1.0884 -0.1884  1.0116 11.6116
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.08839    0.04355 139.817   <2e-16 ***
# natural_gas  0.44911    0.35265   1.274    0.203
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.714 on 1572 degrees of freedom
#   (8 observations deleted due to missingness)
# Multiple R-squared:  0.001031,	Adjusted R-squared:  0.0003952
# F-statistic: 1.622 on 1 and 1572 DF,  p-value: 0.203

# %%
# %%R -i md
# model <- lm(E_CHD ~ E_AGE65 + E_AGE17, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_CHD ~ E_AGE65 + E_AGE17, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1259 -0.8973 -0.1585  0.7186  6.1640
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.766738   0.152203  18.178  < 2e-16 ***
# E_AGE65     0.149739   0.004189  35.749  < 2e-16 ***
# E_AGE17     0.040320   0.005208   7.742 1.74e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.271 on 1571 degrees of freedom
#   (8 observations deleted due to missingness)
# Multiple R-squared:  0.4517,	Adjusted R-squared:  0.451
# F-statistic:   647 on 2 and 1571 DF,  p-value: < 2.2e-16

# %%
# %%R -i md
# model <- lm(E_CHD ~ natural_gas + E_POV200 + E_AFAM + E_HISP + E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR + E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL + E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN + E_RENTER + E_DAYPOP, data=md)
# summary(model)
# Out:
# Call:
# lm(formula = E_CHD ~ natural_gas + E_POV200 + E_AFAM + E_HISP +
#     E_AIAN + E_LIMENG + SPL_SVM_DOM4 + E_UNEMP + E_NOHSDP + E_UNINSUR +
#     E_TOTPOP + E_PARK + E_AGE17 + E_AGE65 + EPL_ROAD + E_RAIL +
#     E_AIRPRT + EPL_IMPWTR + EPL_SMOKE + E_NOINT + E_HOUBDN +
#     E_RENTER + E_DAYPOP, data = md)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.6767 -0.4419  0.0160  0.4530  3.6878
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.206e+00  4.229e-01   2.851 0.004419 **
# natural_gas  -3.865e-02  1.551e-01  -0.249 0.803233
# E_POV200      4.771e-02  2.892e-03  16.496  < 2e-16 ***
# E_AFAM       -4.517e-03  9.031e-04  -5.001 6.35e-07 ***
# E_HISP       -2.201e-02  3.083e-03  -7.140 1.43e-12 ***
# E_AIAN       -5.597e-02  4.169e-02  -1.343 0.179577
# E_LIMENG     -3.577e-02  7.282e-03  -4.912 1.00e-06 ***
# SPL_SVM_DOM4  3.084e-01  4.928e-02   6.259 5.02e-10 ***
# E_UNEMP       1.885e-02  5.965e-03   3.160 0.001609 **
# E_NOHSDP      4.403e-02  4.673e-03   9.421  < 2e-16 ***
# E_UNINSUR     2.049e-02  5.922e-03   3.459 0.000557 ***
# E_TOTPOP     -2.160e-05  1.301e-05  -1.660 0.097116 .
# E_PARK        6.878e-04  2.141e-03   0.321 0.748092
# E_AGE17       4.536e-02  3.716e-03  12.208  < 2e-16 ***
# E_AGE65       1.385e-01  3.091e-03  44.799  < 2e-16 ***
# EPL_ROAD     -8.488e-01  1.267e-01  -6.700 2.93e-11 ***
# E_RAIL        9.988e-04  5.375e-04   1.858 0.063318 .
# E_AIRPRT     -3.605e-03  1.236e-03  -2.917 0.003584 **
# EPL_IMPWTR   -1.683e-01  1.482e-01  -1.135 0.256419
# EPL_SMOKE     3.905e+00  9.505e-01   4.109 4.18e-05 ***
# E_NOINT       2.710e-02  3.419e-03   7.926 4.33e-15 ***
# E_HOUBDN     -4.877e-03  3.104e-03  -1.571 0.116320
# E_RENTER     -1.351e-02  1.314e-03 -10.287  < 2e-16 ***
# E_DAYPOP     -2.344e-05  4.752e-06  -4.934 8.94e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7407 on 1533 degrees of freedom
#   (25 observations deleted due to missingness)
# Multiple R-squared:  0.8162,	Adjusted R-squared:  0.8134
# F-statistic: 295.9 on 23 and 1533 DF,  p-value: < 2.2e-16
